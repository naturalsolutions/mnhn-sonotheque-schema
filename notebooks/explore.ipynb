# %%
import pandas as pd

# %%
df = pd.read_csv("./data/sonotheque1.csv", delimiter=";")
# Out:
# /var/folders/99/kj4r22n55cv1_0hkwlk2tcph0000gn/T/ipykernel_53231/3305962631.py:1: DtypeWarning: Columns (1,2,3,4,5,6,8,10,11,12,13,14,22,23,24,25,26,27,28,29,33,34,35,36,37,41,47,48,50,51,52,53,58,59,60,61,65,66,67,68,69,70,71,72,73,74,75,79,80,81,82,83,86,87,89,90,91,92,96,97,98,99,101,102,103,104,105,109,110,111,112,115,116,117,118,119,123,124,125,126,128,129,130,134,135,136,137,138,141,142,143,144,145,148,152,153,154,155,159,160,161,162,163,165,166,167,173,174,175,176,177) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("./data/sonotheque1.csv", delimiter=";")

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
df.dtypes

# %%
df.head()
# Out:
#    SON_PK                        SON_UID    TYPE  \
# 0   330.0  138070607836168Xe2DOmqTZSKXOU  ESPECE
# 1   441.0  13867749528019ZTeQN2bXAkp7vVn  ESPECE
# 2   441.0  13867749528019ZTeQN2bXAkp7vVn  ESPECE
# 3   441.0  13867749528019ZTeQN2bXAkp7vVn  ESPECE
# 4   441.0  13867749528019ZTeQN2bXAkp7vVn  ESPECE
#
#                                        TITRE INSTITUTION_CODE COLLECTION_CODE  \
# 0  Grillon Luzaridella obscura chant d'appel             MNHN              SO
# 1                         Gryllus campestris             MNHN              SO
# 2                         Gryllus campestris             MNHN              SO
# 3                         Gryllus campestris             MNHN              SO
# 4                         Gryllus campestris             MNHN              SO
#
#   CATALOG_NUMBER  VALIDE VALIDE_PAR  PUBLIE   DATE_PUBLICATION_DEBUT  \
# 0       2014-330     0.0        NaN     1.0  2013-10-03 00:00:00.000
# 1       2014-441     1.0        NaN     1.0  2016-06-30 00:00:00.000
# 2       2014-441     1.0        NaN     1.0  2016-06-30 00:00:00.000
# 3       2014-441     1.0        NaN     1.0  2016-06-30 00:00:00.000
# 4       2014-441     1.0        NaN     1.0  2016-06-30 00:00:00.000
#
#   DATE_PUBLICATION_FIN                           PUBLICATION_SCIENTIFIQUE  \
# 0                  NaN  Desutter-Grandcolas, L. 1992, Bulletin du Musé...
# 1                  NaN                                             [NULL]
# 2                  NaN                                             [NULL]
# 3                  NaN                                             [NULL]
# 4                  NaN                                             [NULL]
#
#                           RECORDER         MICRO  PARABOLE  \
# 0             Sony recorder WM-DC6        ECM929       0.0
# 1  Avisoft recorder-carte son Motu  CM16 Avisoft       0.0
# 2  Avisoft recorder-carte son Motu  CM16 Avisoft       0.0
# 3  Avisoft recorder-carte son Motu  CM16 Avisoft       0.0
# 4  Avisoft recorder-carte son Motu  CM16 Avisoft       0.0
#
#    FREQUENCE_ECHANTILLONNAGE  SUPPORT_ORIGINAL  QUALITE  \
# 0                        0.0              14.0      4.0
# 1                    96000.0              16.0      5.0
# 2                    96000.0              16.0      5.0
# 3                    96000.0              16.0      5.0
# 4                    96000.0              16.0      5.0
#
#    DATE_ENREGISTREMENT_INT  HEURE_ENREGISTREMENT_INT  LIEU_ENREGISTREMENT  \
# 0                1018035.0                      94.0                  NaN
# 1                1030852.0                      -1.0                 18.0
# 2                1030852.0                      -1.0                 18.0
# 3                1030852.0                      -1.0                 18.0
# 4                1030852.0                      -1.0                 18.0
#
#   TEMPERATURE COMMENTAIRES_ENREGISTREMENT           CONTEXTE_COMPORTEMENTAL  \
# 0          23                      [NULL]  Chant d'appel.\r\nSemi-captivité
# 1          26                      [NULL]                appel - male isolé
# 2          26                      [NULL]                appel - male isolé
# 3          26                      [NULL]                appel - male isolé
# 4          26                      [NULL]                appel - male isolé
#
#   HABITAT DESCRIPTION_HABITAT CONTINENT_OCEAN              PAYS  \
# 0     NaN              [NULL]        Amérique  Guyane française
# 1     NaN              [NULL]          Europe            France
# 2     NaN              [NULL]          Europe            France
# 3     NaN              [NULL]          Europe            France
# 4     NaN              [NULL]          Europe            France
#
#                                             LOCALITE   LATITUDE  LONGITUDE  \
# 0  Arataye, affl. Approuagues, 8 km NE pied saut ...        NaN        NaN
# 1                                           Grenoble  45.183586   5.676636
# 2                                           Grenoble  45.183586   5.676636
# 3                                           Grenoble  45.183586   5.676636
# 4                                           Grenoble  45.183586   5.676636
#
#    ALTITUDE                                 COMMENTAIRES  \
# 0       NaN                                       [NULL]
# 1       NaN  Nombreux autres enregistrements disponibles
# 2       NaN  Nombreux autres enregistrements disponibles
# 3       NaN  Nombreux autres enregistrements disponibles
# 4       NaN  Nombreux autres enregistrements disponibles
#
#                    DATECRE                  DATEMAJ USERCRE USERMAJ  \
# 0  2013-10-02 11:27:58.000  2016-02-26 18:01:22.000   User2   User2
# 1  2013-12-11 16:15:52.000  2020-05-18 22:02:11.000   User3   User1
# 2  2013-12-11 16:15:52.000  2020-05-18 22:02:11.000   User3   User1
# 3  2013-12-11 16:15:52.000  2020-05-18 22:02:11.000   User3   User1
# 4  2013-12-11 16:15:52.000  2020-05-18 22:02:11.000   User3   User1
#
#    TELECHARGER_WAV  DEGRE_CERTITUDE  LUMINOSITE       DROITS  \
# 0              0.0            100.0         0.0  cc-by-nc-nd
# 1              0.0            100.0         0.0  cc-by-nc-nd
# 2              0.0            100.0         0.0  cc-by-nc-nd
# 3              0.0            100.0         0.0  cc-by-nc-nd
# 4              0.0            100.0         0.0  cc-by-nc-nd
#
#    SON_MODE_IDENTIFICATION_PK  SON_FK  MODE_IDENTIFICATION  VOCABULAIRE_PK  \
# 0                      3558.0   330.0                 10.0            10.0
# 1                      9311.0   441.0                 10.0            10.0
# 2                      9311.0   441.0                 10.0            10.0
# 3                      9311.0   441.0                 10.0            10.0
# 4                      9311.0   441.0                 10.0            10.0
#
#    VOCABULAIRE_CATEGORIE_FK         LIBELLE_FR         LIBELLE_EN  OLD_PK  \
# 0                       2.0  Etude du spécimen  Etude du spécimen    11.0
# 1                       2.0  Etude du spécimen  Etude du spécimen    11.0
# 2                       2.0  Etude du spécimen  Etude du spécimen    11.0
# 3                       2.0  Etude du spécimen  Etude du spécimen    11.0
# 4                       2.0  Etude du spécimen  Etude du spécimen    11.0
#
#                   DATECRE2                 DATEMAJ3 USERCRE4 USERMAJ5  \
# 0  2016-06-17 10:33:02.000  2016-06-17 10:33:02.000    admin    admin
# 1  2016-06-17 10:33:02.000  2016-06-17 10:33:02.000    admin    admin
# 2  2016-06-17 10:33:02.000  2016-06-17 10:33:02.000    admin    admin
# 3  2016-06-17 10:33:02.000  2016-06-17 10:33:02.000    admin    admin
# 4  2016-06-17 10:33:02.000  2016-06-17 10:33:02.000    admin    admin
#
#    SON_ESPECE_PK  SON_FK6  ESPECE_FK  DEGRE_CERTITUDE7  \
# 0          105.0    330.0       64.0             100.0
# 1          106.0    441.0       65.0             100.0
# 2          106.0    441.0       65.0             100.0
# 3          106.0    441.0       65.0             100.0
# 4          106.0    441.0       65.0             100.0
#
#                   DATECRE8                 DATEMAJ9 USERCRE10 USERMAJ11  \
# 0  2013-10-02 11:27:58.000  2016-02-26 18:01:22.000     User2     User2
# 1  2013-12-11 16:15:52.000  2016-02-09 18:36:42.000     User3     User3
# 2  2013-12-11 16:15:52.000  2016-02-09 18:36:42.000     User3     User3
# 3  2013-12-11 16:15:52.000  2016-02-09 18:36:42.000     User3     User3
# 4  2013-12-11 16:15:52.000  2016-02-09 18:36:42.000     User3     User3
#
#    ESPECE_PK  VALIDE12  GROUPE_TAXONOMIQUE       ORDRE         FAMILLE  \
# 0       64.0       1.0                 1.0  Orthoptera  Phalangopsidae
# 1       65.0       1.0                 1.0  Orthoptera       Gryllidae
# 2       65.0       1.0                 1.0  Orthoptera       Gryllidae
# 3       65.0       1.0                 1.0  Orthoptera       Gryllidae
# 4       65.0       1.0                 1.0  Orthoptera       Gryllidae
#
#          GENRE EPITHETE_SPECIFIQUE EPITHETE_INFRA_SPECIFIQUE  \
# 0  Luzaridella             obscura                       NaN
# 1      Gryllus          campestris                       NaN
# 2      Gryllus          campestris                       NaN
# 3      Gryllus          campestris                       NaN
# 4      Gryllus          campestris                       NaN
#
#                  DESCRIPTEUR                               NOM_SCIENTIFIQUE  \
# 0  Desutter-Grandcolas, 1992  Luzaridella obscura Desutter-Grandcolas, 1992
# 1             Linnaeus, 1758              Gryllus campestris Linnaeus, 1758
# 2             Linnaeus, 1758              Gryllus campestris Linnaeus, 1758
# 3             Linnaeus, 1758              Gryllus campestris Linnaeus, 1758
# 4             Linnaeus, 1758              Gryllus campestris Linnaeus, 1758
#
#                  DATECRE13                DATEMAJ14 USERCRE15 USERMAJ16  \
# 0  2013-10-02 11:19:21.000  2017-01-18 10:13:22.000     User2     User1
# 1  2013-12-11 16:15:52.000  2017-01-17 12:48:53.000     User3     User1
# 2  2013-12-11 16:15:52.000  2017-01-17 12:48:53.000     User3     User1
# 3  2013-12-11 16:15:52.000  2017-01-17 12:48:53.000     User3     User1
# 4  2013-12-11 16:15:52.000  2017-01-17 12:48:53.000     User3     User1
#
#    NOM_VERNACULAIRE_PK  ESPECE_FK17  LANG                       NOM  \
# 0                  NaN          NaN   NaN                       NaN
# 1               1880.0         65.0   NaN         Grillon champêtre
# 2               1879.0         65.0   NaN  Petit Cheval du Bon Dieu
# 3               1882.0         65.0   NaN           Grillon sauvage
# 4               1881.0         65.0   NaN        Grillon des champs
#
#                  DATECRE18                DATEMAJ19 USERCRE20 USERMAJ21  \
# 0                      NaN                      NaN       NaN       NaN
# 1  2017-01-17 12:48:53.000  2017-01-17 12:48:53.000     User1     User1
# 2  2017-01-17 12:48:53.000  2017-01-17 12:48:53.000     User1     User1
# 3  2017-01-17 12:48:53.000  2017-01-17 12:48:53.000     User1     User1
# 4  2017-01-17 12:48:53.000  2017-01-17 12:48:53.000     User1     User1
#
#    VOCABULAIRE_PK22  VOCABULAIRE_CATEGORIE_FK23 LIBELLE_FR24 LIBELLE_EN25  \
# 0               1.0                         1.0     Insectes      Insects
# 1               1.0                         1.0     Insectes      Insects
# 2               1.0                         1.0     Insectes      Insects
# 3               1.0                         1.0     Insectes      Insects
# 4               1.0                         1.0     Insectes      Insects
#
#    OLD_PK26                DATECRE27                DATEMAJ28 USERCRE29  \
# 0       1.0  2016-06-17 10:33:02.000  2016-06-17 10:33:02.000     admin
# 1       1.0  2016-06-17 10:33:02.000  2016-06-17 10:33:02.000     admin
# 2       1.0  2016-06-17 10:33:02.000  2016-06-17 10:33:02.000     admin
# 3       1.0  2016-06-17 10:33:02.000  2016-06-17 10:33:02.000     admin
# 4       1.0  2016-06-17 10:33:02.000  2016-06-17 10:33:02.000     admin
#
#   USERMAJ30  SON_AUTEUR_PK  SON_FK31  AUTEUR_FK                DATECRE32  \
# 0     admin          105.0     330.0       13.0  2013-10-02 11:27:58.000
# 1     admin          106.0     441.0        7.0  2013-12-11 16:15:52.000
# 2     admin          106.0     441.0        7.0  2013-12-11 16:15:52.000
# 3     admin          106.0     441.0        7.0  2013-12-11 16:15:52.000
# 4     admin          106.0     441.0        7.0  2013-12-11 16:15:52.000
#
#                  DATEMAJ33 USERCRE34 USERMAJ35  AUTEUR_PK  NOM36  \
# 0  2016-02-26 18:01:22.000     User2     User2       13.0  User2
# 1  2016-02-09 18:36:42.000     User3     User3        7.0  User3
# 2  2016-02-09 18:36:42.000     User3     User3        7.0  User3
# 3  2016-02-09 18:36:42.000     User3     User3        7.0  User3
# 4  2016-02-09 18:36:42.000     User3     User3        7.0  User3
#
#                  DATECRE37                DATEMAJ38 USERCRE39 USERMAJ40  \
# 0  2013-10-02 15:40:15.000  2016-02-26 17:47:39.000     User2     User2
# 1  2013-10-04 11:47:02.000  2016-02-09 13:57:35.000     User1     User3
# 2  2013-10-04 11:47:02.000  2016-02-09 13:57:35.000     User1     User3
# 3  2013-10-04 11:47:02.000  2016-02-09 13:57:35.000     User1     User3
# 4  2013-10-04 11:47:02.000  2016-02-09 13:57:35.000     User1     User3
#
#    SON_MOT_CLE_PK  SON_FK41  MOT_CLE_FK DATECRE42 DATEMAJ43 USERCRE44  \
# 0             NaN       NaN         NaN       NaN       NaN       NaN
# 1             NaN       NaN         NaN       NaN       NaN       NaN
# 2             NaN       NaN         NaN       NaN       NaN       NaN
# 3             NaN       NaN         NaN       NaN       NaN       NaN
# 4             NaN       NaN         NaN       NaN       NaN       NaN
#
#   USERMAJ45  MOT_CLE_PK  LANG46 LIBELLE DATECRE47 DATEMAJ48 USERCRE49  \
# 0       NaN         NaN     NaN     NaN       NaN       NaN       NaN
# 1       NaN         NaN     NaN     NaN       NaN       NaN       NaN
# 2       NaN         NaN     NaN     NaN       NaN       NaN       NaN
# 3       NaN         NaN     NaN     NaN       NaN       NaN       NaN
# 4       NaN         NaN     NaN     NaN       NaN       NaN       NaN
#
#   USERMAJ50  SON_SPECIMEN_PK  SON_FK51  SPECIMEN_FK DATECRE52 DATEMAJ53  \
# 0       NaN              NaN       NaN          NaN       NaN       NaN
# 1       NaN              NaN       NaN          NaN       NaN       NaN
# 2       NaN              NaN       NaN          NaN       NaN       NaN
# 3       NaN              NaN       NaN          NaN       NaN       NaN
# 4       NaN              NaN       NaN          NaN       NaN       NaN
#
#   USERCRE54 USERMAJ55  SPECIMEN_PK INSTITUTION_CODE56 COLLECTION_CODE57  \
# 0       NaN       NaN          NaN                NaN               NaN
# 1       NaN       NaN          NaN                NaN               NaN
# 2       NaN       NaN          NaN                NaN               NaN
# 3       NaN       NaN          NaN                NaN               NaN
# 4       NaN       NaN          NaN                NaN               NaN
#
#   CATALOG_NUMBER58  DATE_COLLECTE_INT  HEURE_COLLECTE_INT  LUMINOSITE59  \
# 0              NaN                NaN                 NaN           NaN
# 1              NaN                NaN                 NaN           NaN
# 2              NaN                NaN                 NaN           NaN
# 3              NaN                NaN                 NaN           NaN
# 4              NaN                NaN                 NaN           NaN
#
#   COLLECTEUR DATECRE60 DATEMAJ61 USERCRE62 USERMAJ63  FICHIER_SON_PK  \
# 0        NaN       NaN       NaN       NaN       NaN           171.0
# 1        NaN       NaN       NaN       NaN       NaN           173.0
# 2        NaN       NaN       NaN       NaN       NaN           173.0
# 3        NaN       NaN       NaN       NaN       NaN           173.0
# 4        NaN       NaN       NaN       NaN       NaN           173.0
#
#    SON_FK64                    FICHIER_UID TYPE65  \
# 0     330.0  138070610403976zVnynBeWnWh7lT    MP3
# 1     441.0  1453824248000YEjjaaH69KxXmDEj    MP3
# 2     441.0  1453824248000YEjjaaH69KxXmDEj    MP3
# 3     441.0  1453824248000YEjjaaH69KxXmDEj    MP3
# 4     441.0  1453824248000YEjjaaH69KxXmDEj    MP3
#
#                           PATH                           FILENAME   MIME_TYPE  \
# 0  2013/10/02/MNHN_SO_2014-330  138070610403976zVnynBeWnWh7lT.mp3  audio/mpeg
# 1  2016/01/26/MNHN_SO_2014-441  1453824248000YEjjaaH69KxXmDEj.mp3  audio/mpeg
# 2  2016/01/26/MNHN_SO_2014-441  1453824248000YEjjaaH69KxXmDEj.mp3  audio/mpeg
# 3  2016/01/26/MNHN_SO_2014-441  1453824248000YEjjaaH69KxXmDEj.mp3  audio/mpeg
# 4  2016/01/26/MNHN_SO_2014-441  1453824248000YEjjaaH69KxXmDEj.mp3  audio/mpeg
#
#      TAILLE      CHECKSUM DUREE  BITSPERSAMPLE  CHANNELS  \
# 0  945127.0  3.117388e+09   NaN           16.0       1.0
# 1  478848.0  8.858092e+08   NaN           16.0       1.0
# 2  478848.0  8.858092e+08   NaN           16.0       1.0
# 3  478848.0  8.858092e+08   NaN           16.0       1.0
# 4  478848.0  8.858092e+08   NaN           16.0       1.0
#
#    FREQUENCE_ECHANTILLONNAGE66                DATECRE67  \
# 0                          0.0  2013-10-02 11:27:58.000
# 1                      96000.0  2013-12-11 16:15:52.000
# 2                      96000.0  2013-12-11 16:15:52.000
# 3                      96000.0  2013-12-11 16:15:52.000
# 4                      96000.0  2013-12-11 16:15:52.000
#
#                  DATEMAJ68 USERCRE69 USERMAJ70  SON_IMAGE_PK  SON_FK71  \
# 0  2016-02-26 18:01:22.000     User2     User2         227.0     330.0
# 1  2016-02-09 18:36:42.000     User3     User3         230.0     441.0
# 2  2016-02-09 18:36:42.000     User3     User3         230.0     441.0
# 3  2016-02-09 18:36:42.000     User3     User3         230.0     441.0
# 4  2016-02-09 18:36:42.000     User3     User3         230.0     441.0
#
#    IMAGE_FK    TYPE72                DATECRE73                DATEMAJ74  \
# 0       9.0  VIGNETTE  2013-10-02 11:27:58.000  2016-02-26 18:01:22.000
# 1     193.0  WAVEFORM  2016-06-20 18:10:09.000  2016-06-20 18:10:09.000
# 2     193.0  WAVEFORM  2016-06-20 18:10:09.000  2016-06-20 18:10:09.000
# 3     193.0  WAVEFORM  2016-06-20 18:10:09.000  2016-06-20 18:10:09.000
# 4     193.0  WAVEFORM  2016-06-20 18:10:09.000  2016-06-20 18:10:09.000
#
#   USERCRE75 USERMAJ76  IMAGE_PK                      IMAGE_UID       ID  \
# 0     User2     User2       9.0  1466155938028Ys4MWYthQnHM92SL  Grillon
# 1     User3     User3     193.0  1466439009826Fdd0z6K3bwCozrUT      NaN
# 2     User3     User3     193.0  1466439009826Fdd0z6K3bwCozrUT      NaN
# 3     User3     User3     193.0  1466439009826Fdd0z6K3bwCozrUT      NaN
# 4     User3     User3     193.0  1466439009826Fdd0z6K3bwCozrUT      NaN
#
#   MIME_TYPE77  MODELE  TAILLE78    CHECKSUM79  LARGEUR  HAUTEUR CREDIT  \
# 0   image/png     1.0   36233.0  2.735275e+09    800.0    450.0    NaN
# 1   image/png     0.0    2399.0  2.147270e+09    800.0    450.0    NaN
# 2   image/png     0.0    2399.0  2.147270e+09    800.0    450.0    NaN
# 3   image/png     0.0    2399.0  2.147270e+09    800.0    450.0    NaN
# 4   image/png     0.0    2399.0  2.147270e+09    800.0    450.0    NaN
#
#                  DATECRE80                DATEMAJ81 USERCRE82 USERMAJ83
# 0  2016-06-17 11:32:18.000  2016-06-23 10:34:20.000     admin     User8
# 1  2016-06-20 18:10:09.000  2016-06-20 18:10:09.000     User3     User3
# 2  2016-06-20 18:10:09.000  2016-06-20 18:10:09.000     User3     User3
# 3  2016-06-20 18:10:09.000  2016-06-20 18:10:09.000     User3     User3
# 4  2016-06-20 18:10:09.000  2016-06-20 18:10:09.000     User3     User3

# %%
print(
    "DataFrame Metrics: Number of Rows =",
    df.shape[0],
    ", Number of Columns =",
    df.shape[1],
)
# Out:
# DataFrame Metrics: Number of Rows = 1048575 , Number of Columns = 178

# %%
def print_unique_values_and_counts(df, column_name):
    """
    Print unique values and their counts for a specified column in a pandas DataFrame.

    Parameters:
    df (pd.DataFrame): The DataFrame to analyze.
    column_name (str): The name of the column to analyze.
    """
    if column_name in df.columns:
        value_counts = df[column_name].value_counts()
        print(f"Unique values and counts for column '{column_name}':\n{value_counts}")
    else:
        print(f"Column '{column_name}' not found in DataFrame.")

# %%
def count_aggregate_values(df, column_name):
    """
    Return a count aggregate of all different values in a specified column of a pandas DataFrame.

    Parameters:
    df (pd.DataFrame): The DataFrame to analyze.
    column_name (str): The name of the column to analyze.

    Returns:
    pd.Series: A series containing counts of unique values in the specified column.
    """
    if column_name in df.columns:
        return len(df[column_name].value_counts())
    else:
        raise ValueError(f"Column '{column_name}' not found in DataFrame.")

# %%
def aggregate_and_iterate(df, group_column, agg_column):
    """
    Aggregate values from a DataFrame on a given column and iterate over the results.

    Parameters:
    df (pd.DataFrame): The DataFrame to analyze.
    group_column (str): The name of the column to group by.
    agg_column (str): The name of the column to aggregate.

    Returns:
    None
    """
    aggregated_df = df.groupby(group_column)[agg_column].sum().reset_index()
    for index, row in aggregated_df.iterrows():
        print(f"Group: {row[group_column]}, Aggregated Value: {row[agg_column]}")

# %%
# 1. Iterate scientic names
# 2. Search GBIF
# 3. map to CSV Export, use a class here SpeciesExporter < Exporter
# Out:
# Unique values and counts for column 'DUREE':
# DUREE
# 00:30       91092
# 00:02        2404
# 01:00        1616
# 00:16        1346
# 00:20        1265
#             ...
# 16:25           2
# 15:56           2
# 26:13:00        2
# 79:38:00        2
# 16:26           2
# Name: count, Length: 1419, dtype: int64

# %%
count_aggregate_values(df, "NOM_SCIENTIFIQUE")
# Out:
# 1702

# %%
aggregated_df = df.groupby("NOM_SCIENTIFIQUE")

# %%
scientific_names = df["NOM_SCIENTIFIQUE"].unique().tolist()
len(scientific_names)
# Out:
# 1703

# %%
import pandas as pd
from pygbif import species


def fetch_gbif_results(names_list):
    """
    Fetch results from GBIF for each name in the list and create a pandas DataFrame.

    Parameters:
    names_list (list): A list of scientific names to search in GBIF.

    Returns:
    pd.DataFrame: A DataFrame containing the results from GBIF.
    """
    results = []

    for name in names_list:
        try:
            result = species.name_suggest(q=name)
            if result:
                for entry in result:
                    # Extract relevant fields from the entry
                    result_data = {
                        "sonotheque_scientific_name": name,
                        "key": entry.get("key"),
                        "nameKey": entry.get("nameKey"),
                        "vernacular_name": entry.get("vernacularNames"),
                        "kingdom": entry.get("kingdom"),
                        "phylum": entry.get("phylum"),
                        "class": entry.get("class"),
                        "order": entry.get("order"),
                        "family": entry.get("family"),
                        "genus": entry.get("genus"),
                        "species": entry.get("species"),
                        "scientific_name": entry.get("scientificName"),
                        "canonical_name": entry.get("canonicalName"),
                        "vernacular_name_original": entry.get(
                            "vernacularNamesOriginal"
                        ),
                        "vernacular_name_english": entry.get("vernacularNamesEnglish"),
                        "vernacular_name_french": entry.get("vernacularNamesFrench"),
                        "rank": entry.get("rank"),
                        "status": entry.get("status"),
                        "synonym": entry.get("synonym"),
                    }
                    results.append(result_data)
        except Exception as e:
            print(f"Error fetching data for {name}: {e}")

    # Convert the list of dictionaries to a DataFrame
    df_results = pd.DataFrame(results)
    return df_results

# %%
scientific_names = df["NOM_SCIENTIFIQUE"].unique().tolist()
df_gbif_results = fetch_gbif_results(scientific_names)
print(df_gbif_results.head())

# %%
df_gbif_results.to_csv("./data/gbif_results.csv", index=False)
df_gbif_results.to_excel("./data/gbif_results.xlsx", index=False)

# %%
print(scientific_names[160::260])
# Out:
# ['Alopochen aegyptiacus (Linnaeus, 1766)', 'Coccycua minuta (Vieillot, 1817)', 'Falco biarmicus Temminck, 1825', 'Phoeniculus purpureus (Miller, JF, 1784)', 'Sturnus vulgaris Linnaeus, 1758', 'Psarisomus dalhousiae (Jameson, 1835)']

# %%
from fuzzywuzzy import fuzz


def similar(a, b):
    return fuzz.ratio(a, b)
# Out:
# /Users/gaetan/.pyenv/versions/3.10.12/envs/3m-ai-dataprep-env/lib/python3.10/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
import re
from rapidfuzz import fuzz, process


def custom_scorer(s1, s2):
    """
    Custom scoring function that considers both integer and non-integer parts of the strings.

    Parameters:
    s1 (str): The first string to compare.
    s2 (str): The second string to compare.

    Returns:
    int: The similarity score between the two strings.
    """
    # Extract integer parts
    int_part1 = "".join(re.findall(r"\d+", s1))
    int_part2 = "".join(re.findall(r"\d+", s2))

    # Extract non-integer parts
    non_int_part1 = re.sub(r"\d+", "", s1)
    non_int_part2 = re.sub(r"\d+", "", s2)

    # Calculate similarity scores
    int_score = fuzz.ratio(int_part1, int_part2)
    non_int_score = fuzz.ratio(non_int_part1, non_int_part2)

    # Combine scores with more weight to integer parts
    combined_score = 0.6 * int_score + 0.4 * non_int_score
    return combined_score


def deduplicate_list(strings_list, threshold=90):
    """
    Deduplicate very close entries in a list of strings using a custom scoring function.

    Parameters:
    strings_list (list): The list of strings to deduplicate.
    threshold (int): The similarity threshold for deduplication (default is 90).

    Returns:
    list: A deduplicated list of strings.
    """
    # Use rapidfuzz to deduplicate with the custom scorer
    deduped_list = list(
        process.dedupe(strings_list, scorer=custom_scorer, score_cutoff=threshold)
    )

    return deduped_list

# %%
# Example usage
deduped_list = deduplicate_list(scientific_names, threshold=90)
print(deduped_list)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Example usage
# ----> 2 deduped_list = deduplicate_list(scientific_names, threshold=90)
#       3 print(deduped_list)
#
# Cell In[9], line 46, in deduplicate_list(strings_list, threshold)
#      34 """
#      35 Deduplicate very close entries in a list of strings using a custom scoring function.
#      36
#    (...)
#      42 list: A deduplicated list of strings.
#      43 """
#      44 # Use rapidfuzz to deduplicate with the custom scorer
#      45 deduped_list = list(
# ---> 46     process.dedupe(strings_list, scorer=custom_scorer, score_cutoff=threshold)
#      47 )
#      49 return deduped_list
#
# AttributeError: module 'rapidfuzz.process' has no attribute 'dedupe'
