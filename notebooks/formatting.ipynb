# %%
import pandas as pd
import dask.dataframe as dd
# Out:
# /Users/gaetan/.pyenv/versions/3.10.12/envs/sonotheque-env/lib/python3.10/site-packages/dask/dataframe/_pyarrow_compat.py:17: FutureWarning: Minimal version of pyarrow will soon be increased to 14.0.1. You are using 10.0.1. Please consider upgrading.
#   warnings.warn(

# %%
file_path = "./data/sonotheque1.csv"
dtypes = {
    "SON_PK": "int64",
    "SON_UID": "object",
    "TYPE": "object",
    "TITRE": "object",
    "INSTITUTION_CODE": "object",
    "COLLECTION_CODE": "object",
    "CATALOG_NUMBER": "object",
    "VALIDE": "int64",
    "VALIDE_PAR": "object",
    "PUBLIE": "int64",
    "DATE_PUBLICATION_DEBUT": "object",
    "DATE_PUBLICATION_FIN": "object",
    "PUBLICATION_SCIENTIFIQUE": "object",
    "RECORDER": "object",
    "MICRO": "object",
    "PARABOLE": "int64",
    "FREQUENCE_ECHANTILLONNAGE": "int64",
    "SUPPORT_ORIGINAL": "int64",
    "QUALITE": "int64",
    "DATE_ENREGISTREMENT_INT": "int64",
    "HEURE_ENREGISTREMENT_INT": "int64",
    "LIEU_ENREGISTREMENT": "int64",
    "TEMPERATURE": "object",
    "COMMENTAIRES_ENREGISTREMENT": "object",
    "CONTEXTE_COMPORTEMENTAL": "object",
    "HABITAT": "object",
    "DESCRIPTION_HABITAT": "object",
    "CONTINENT_OCEAN": "object",
    "PAYS": "object",
    "LOCALITE": "object",
    "LATITUDE": "float64",
    "LONGITUDE": "float64",
    "ALTITUDE": "int64",
    "COMMENTAIRES": "object",
    "DATECRE": "object",
    "DATEMAJ": "object",
    "USERCRE": "object",
    "USERMAJ": "object",
    "TELECHARGER_WAV": "int64",
    "DEGRE_CERTITUDE": "int64",
    "LUMINOSITE": "int64",
    "DROITS": "object",
    "SON_MODE_IDENTIFICATION_PK": "int64",
    "SON_FK": "int64",
    "MODE_IDENTIFICATION": "int64",
    "VOCABULAIRE_PK": "int64",
    "VOCABULAIRE_CATEGORIE_FK": "int64",
    "LIBELLE_FR": "object",
    "LIBELLE_EN": "object",
    "OLD_PK": "int64",
    "DATECRE2": "object",
    "DATEMAJ3": "object",
    "USERCRE4": "object",
    "USERMAJ5": "object",
    "SON_ESPECE_PK": "int64",
    "SON_FK6": "int64",
    "ESPECE_FK": "int64",
    "DEGRE_CERTITUDE7": "int64",
    "DATECRE8": "object",
    "DATEMAJ9": "object",
    "USERCRE10": "object",
    "USERMAJ11": "object",
    "ESPECE_PK": "int64",
    "VALIDE12": "int64",
    "GROUPE_TAXONOMIQUE": "int64",
    "ORDRE": "object",
    "FAMILLE": "object",
    "GENRE": "object",
    "EPITHETE_SPECIFIQUE": "object",
    "EPITHETE_INFRA_SPECIFIQUE": "object",
    "DESCRIPTEUR": "object",
    "NOM_SCIENTIFIQUE": "object",
    "DATECRE13": "object",
    "DATEMAJ14": "object",
    "USERCRE15": "object",
    "USERMAJ16": "object",
    "NOM_VERNACULAIRE_PK": "int64",
    "ESPECE_FK17": "int64",
    "LANG": "int64",
    "NOM": "object",
    "DATECRE18": "object",
    "DATEMAJ19": "object",
    "USERCRE20": "object",
    "USERMAJ21": "object",
    "VOCABULAIRE_PK22": "int64",
    "VOCABULAIRE_CATEGORIE_FK23": "int64",
    "LIBELLE_FR24": "object",
    "LIBELLE_EN25": "object",
    "OLD_PK26": "int64",
    "DATECRE27": "object",
    "DATEMAJ28": "object",
    "USERCRE29": "object",
    "USERMAJ30": "object",
    "SON_AUTEUR_PK": "int64",
    "SON_FK31": "int64",
    "AUTEUR_FK": "int64",
    "DATECRE32": "object",
    "DATEMAJ33": "object",
    "USERCRE34": "object",
    "USERMAJ35": "object",
    "AUTEUR_PK": "int64",
    "NOM36": "object",
    "DATECRE37": "object",
    "DATEMAJ38": "object",
    "USERCRE39": "object",
    "USERMAJ40": "object",
    "SON_MOT_CLE_PK": "int64",
    "SON_FK41": "int64",
    "MOT_CLE_FK": "int64",
    "DATECRE42": "object",
    "DATEMAJ43": "object",
    "USERCRE44": "object",
    "USERMAJ45": "object",
    "MOT_CLE_PK": "int64",
    "LANG46": "int64",
    "LIBELLE": "object",
    "DATECRE47": "object",
    "DATEMAJ48": "object",
    "USERCRE49": "object",
    "USERMAJ50": "object",
    "SON_SPECIMEN_PK": "int64",
    "SON_FK51": "int64",
    "SPECIMEN_FK": "int64",
    "DATECRE52": "object",
    "DATEMAJ53": "object",
    "USERCRE54": "object",
    "USERMAJ55": "object",
    "SPECIMEN_PK": "int64",
    "INSTITUTION_CODE56": "object",
    "COLLECTION_CODE57": "object",
    "CATALOG_NUMBER58": "object",
    "DATE_COLLECTE_INT": "int64",
    "HEURE_COLLECTE_INT": "int64",
    "LUMINOSITE59": "int64",
    "COLLECTEUR": "object",
    "DATECRE60": "object",
    "DATEMAJ61": "object",
    "USERCRE62": "object",
    "USERMAJ63": "object",
    "FICHIER_SON_PK": "int64",
    "SON_FK64": "int64",
    "FICHIER_UID": "object",
    "TYPE65": "object",
    "PATH": "object",
    "FILENAME": "object",
    "MIME_TYPE": "object",
    "TAILLE": "int64",
    "CHECKSUM": "int64",
    "DUREE": "object",
    "BITSPERSAMPLE": "int64",
    "CHANNELS": "int64",
    "FREQUENCE_ECHANTILLONNAGE66": "int64",
    "DATECRE67": "object",
    "DATEMAJ68": "object",
    "USERCRE69": "object",
    "USERMAJ70": "object",
    "SON_IMAGE_PK": "int64",
    "SON_FK71": "int64",
    "IMAGE_FK": "int64",
    "TYPE72": "object",
    "DATECRE73": "object",
    "DATEMAJ74": "object",
    "USERCRE75": "object",
    "USERMAJ76": "object",
    "IMAGE_PK": "int64",
    "IMAGE_UID": "object",
    "ID": "object",
    "MIME_TYPE77": "object",
    "MODELE": "int64",
    "TAILLE78": "int64",
    "CHECKSUM79": "int64",
    "LARGEUR": "int64",
    "HAUTEUR": "int64",
    "CREDIT": "object",
    "DATECRE80": "object",
    "DATEMAJ81": "object",
    "USERCRE82": "object",
    "USERMAJ83": "object",
}
# Columns that might contain missing values
# assume_missing = ["COMMENTAIRES", "DESCRIPTION_HABITAT", "ALTITUDE"]

# Columns that should be parsed as dates
date_cols = [
    "DATECRE",
    "DATEMAJ",
    "DATE_PUBLICATION_DEBUT",
    "DATE_PUBLICATION_FIN",
    "DATEMAJ3",
    "DATEMAJ9",
    "DATEMAJ14",
    "DATEMAJ19",
    "DATEMAJ28",
    "DATEMAJ33",
    "DATEMAJ38",
    "DATEMAJ43",
    "DATEMAJ48",
    "DATEMAJ53",
    "DATEMAJ61",
    "DATEMAJ68",
    "DATEMAJ74",
    "DATEMAJ81",
    "DATECRE2",
    "DATECRE8",
    "DATECRE13",
    "DATECRE18",
    "DATECRE27",
    "DATECRE32",
    "DATECRE37",
    "DATECRE42",
    "DATECRE47",
    "DATECRE52",
    "DATECRE60",
    "DATECRE67",
    "DATECRE73",
    "DATECRE80",
]
# Read the CSV file into a Dask DataFrame
df = dd.read_csv(
    file_path,
    sep=";",
    quotechar='"',
    dtype=dtypes,
    # assume_missing=assume_missing,
    # sample=5000,  # Increase sample size for better type inference
    # blocksize="25MB",  # Adjust based on your file size and available memory
    # encoding="utf-8",  # Specify encoding if needed
    # on_bad_lines="warn",  # Warn about problematic lines instead of failing
    # low_memory=False,  # Disable pandas' dtype inference
    parse_dates=date_cols,
)

pdf = df.compute().head(3000)
print(pdf.dtypes)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/.pyenv/versions/3.10.12/envs/sonotheque-env/lib/python3.10/site-packages/dask/backends.py in wrapper(*args, **kwargs)
#     135                 try:
# --> 136                     return func(*args, **kwargs)
#     137                 except Exception as e:
#
# ~/.pyenv/versions/3.10.12/envs/sonotheque-env/lib/python3.10/site-packages/dask/dataframe/io/csv.py in read(urlpath, blocksize, lineterminator, compression, sample, sample_rows, enforce, assume_missing, storage_options, include_path_column, **kwargs)
#     762     ):
# --> 763         return read_pandas(
#     764             reader,
#
# ...

# %%
import duckdb
import pandas as pd

# Read CSV file using DuckDB
query = """
SELECT *
FROM read_csv('./data/sonotheque1.csv', 
                   header=True, 
                   delim=';')
"""
con = duckdb.connect(database=":memory:")
df_duck = con.execute(query).fetchdf()

# Print column types
print("Column types from DuckDB:")
for column, dtype in df_duck.dtypes.items():
    print(f"{column}: {dtype}")

# Columns that should be parsed as dates
date_cols = [
    "DATECRE",
    "DATEMAJ",
    "DATE_PUBLICATION_DEBUT",
    "DATE_PUBLICATION_FIN",
    "DATEMAJ3",
    "DATEMAJ9",
    "DATEMAJ14",
    "DATEMAJ19",
    "DATEMAJ28",
    "DATEMAJ33",
    "DATEMAJ38",
    "DATEMAJ43",
    "DATEMAJ48",
    "DATEMAJ53",
    "DATEMAJ61",
    "DATEMAJ68",
    "DATEMAJ74",
    "DATEMAJ81",
    "DATECRE2",
    "DATECRE8",
    "DATECRE13",
    "DATECRE18",
    "DATECRE27",
    "DATECRE32",
    "DATECRE37",
    "DATECRE42",
    "DATECRE47",
    "DATECRE52",
    "DATECRE60",
    "DATECRE67",
    "DATECRE73",
    "DATECRE80",
]

# Compare with pandas dtypes
print("\nComparing with pandas dtypes:")
df_pandas = pd.read_csv(
    "./data/sonotheque1.csv",
    sep=";",
    nrows=30000,
    quotechar='"',
    parse_dates=date_cols,
    low_memory=False,
)
for column in df_duck.columns:
    duck_type = df_duck[column].dtype
    pandas_type = df_pandas[column].dtype
    if duck_type != pandas_type:
        print(f"{column}: DuckDB - {duck_type}, Pandas - {pandas_type}")

con.close()
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Column types from DuckDB:
# SON_PK: float64
# SON_UID: object
# TYPE: object
# TITRE: object
# INSTITUTION_CODE: object
# COLLECTION_CODE: object
# CATALOG_NUMBER: object
# VALIDE: float64
# VALIDE_PAR: object
# PUBLIE: float64
# DATE_PUBLICATION_DEBUT: datetime64[us]
# DATE_PUBLICATION_FIN: datetime64[us]
# PUBLICATION_SCIENTIFIQUE: object
# RECORDER: object
# MICRO: object
# PARABOLE: float64
# FREQUENCE_ECHANTILLONNAGE: float64
# SUPPORT_ORIGINAL: float64
# QUALITE: float64
# DATE_ENREGISTREMENT_INT: float64
# HEURE_ENREGISTREMENT_INT: float64
# LIEU_ENREGISTREMENT: float64
# TEMPERATURE: object
# COMMENTAIRES_ENREGISTREMENT: object
# CONTEXTE_COMPORTEMENTAL: object
# HABITAT: object
# DESCRIPTION_HABITAT: object
# CONTINENT_OCEAN: object
# PAYS: object
# LOCALITE: object
# LATITUDE: float64
# LONGITUDE: float64
# ALTITUDE: float64
# COMMENTAIRES: object
# DATECRE: datetime64[us]
# ...

# %%
class SchemaConverter:
    def __init__(self, df, exclude_unmapped_initial_columns=False):
        self.df = df
        self.conversion_dict = {
            "SON_PK": "son_primary_key",
            "SON_UID": "son_unique_id",
            "TYPE": "type",
            "TITRE": "title",
            "INSTITUTION_CODE": "institution_code",
            "COLLECTION_CODE": "collection_code",
            "CATALOG_NUMBER": "catalog_number",
            "VALIDE": "valid",
            "VALIDE_PAR": "validated_by",
            "PUBLIE": "published",
            "DATE_PUBLICATION_DEBUT": "publication_start_date",
            "DATE_PUBLICATION_FIN": "publication_end_date",
            "PUBLICATION_SCIENTIFIQUE": "scientific_publication",
            "RECORDER": "recorder",
            "MICRO": "micro",
            "PARABOLE": "parabola",
            "FREQUENCE_ECHANTILLONNAGE": "sampling_frequency",
            "SUPPORT_ORIGINAL": "original_support",
            "QUALITE": "quality",
            "DATE_ENREGISTREMENT_INT": "registration_date_int",
            "HEURE_ENREGISTREMENT_INT": "registration_time_int",
            "LIEU_ENREGISTREMENT": "registration_place",
            "TEMPERATURE": "temperature",
            "COMMENTAIRES_ENREGISTREMENT": "registration_comments",
            "CONTEXTE_COMPORTEMENTAL": "behavioral_context",
            "HABITAT": "habitat",
            "DESCRIPTION_HABITAT": "habitat_description",
            "CONTINENT_OCEAN": "continent_ocean",
            "PAYS": "country",
            "LOCALITE": "locality",
            "LATITUDE": "latitude",
            "LONGITUDE": "longitude",
            "ALTITUDE": "altitude",
            "COMMENTAIRES": "comments",
            "DATECRE": "creation_date",
            "DATEMAJ": "last_modified_date",
            "USERCRE": "created_by",
            "USERMAJ": "modified_by",
            # Add more conversions as needed
        }
        self.exclude_unmapped_initial_columns = exclude_unmapped_initial_columns
        self.aggregated_sound_df = None

    def convert_schema(self):
        custom_schema = {}
        for column in self.df.columns:
            custom_name = self.conversion_dict.get(
                column, column
            )  # Use original name if not found
            if custom_name != column:  # Only infclude mapped columns
                custom_schema[custom_name] = column
                self.df.rename(
                    columns={column: custom_name}, inplace=True
                )  # Rename columns in the original dataframe
            if self.exclude_unmapped_initial_columns:
                self.df = self.df[
                    self.df.columns.intersection(self.conversion_dict.values())
                ]
        return custom_schema

    def aggregate_by_primary_key(self):
        if "son_primary_key" not in self.df.columns:
            raise ValueError(
                "The 'son_primary_key' column is not present in the dataframe."
            )

        # Group by 'son_primary_key' and aggregate all other columns
        # legacy keep only first value
        # aggregated_df = self.df.groupby("son_primary_key").agg(lambda x: x.iloc[0])

        # We use 'first' to keep only the first value for each group
        aggregated_df = (
            self.df.groupby("son_primary_key")
            .agg(lambda x: x.tolist())
            .map(lambda x: list(set(x)))
            .map(lambda x: x[0] if len(x) == 1 else x)
            .map(
                lambda x: pd.NA
                if isinstance(x, list) and all(pd.isna(item) for item in x)
                else x
            )
        )

        # Reset the index to make 'son_primary_key' a regular column again
        aggregated_df = aggregated_df.reset_index()
        print(aggregated_df.head(10))

        # Update the dataframe in place
        self.aggregated_sound_df = aggregated_df

        return self.aggregated_sound_df

# %%
# Usage
converter = SchemaConverter(df_pandas, exclude_unmapped_initial_columns=True)
custom_schema = converter.convert_schema()

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
converter.df.head(10)
# Out:
#    son_primary_key                  son_unique_id    type  \
# 0              330  138070607836168Xe2DOmqTZSKXOU  ESPECE
# 1              441  13867749528019ZTeQN2bXAkp7vVn  ESPECE
# 2              441  13867749528019ZTeQN2bXAkp7vVn  ESPECE
# 3              441  13867749528019ZTeQN2bXAkp7vVn  ESPECE
# 4              441  13867749528019ZTeQN2bXAkp7vVn  ESPECE
# 5              441  13867749528019ZTeQN2bXAkp7vVn  ESPECE
# 6              441  13867749528019ZTeQN2bXAkp7vVn  ESPECE
# 7              441  13867749528019ZTeQN2bXAkp7vVn  ESPECE
# 8              441  13867749528019ZTeQN2bXAkp7vVn  ESPECE
# 9              441  13867749528019ZTeQN2bXAkp7vVn  ESPECE
#
#                                        title institution_code collection_code  \
# 0  Grillon Luzaridella obscura chant d'appel             MNHN              SO
# 1                         Gryllus campestris             MNHN              SO
# 2                         Gryllus campestris             MNHN              SO
# ...

# %%
len(agg_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/99/kj4r22n55cv1_0hkwlk2tcph0000gn/T/ipykernel_24361/663823377.py in <cell line: 1>()
# ----> 1 len(agg_df)
#
# NameError: name 'agg_df' is not defined
