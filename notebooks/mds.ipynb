# %%
import duckdb
import ibis
from ibis import _

# %%
import os

# Check if the file exists, if not, create it
if not os.path.exists('./db/sonotheque.duckdb'):
    # Create an empty DuckDB file
    duckdb.connect('./db/sonotheque.duckdb').close()
    print("Created sonotheque.duckdb file.")
else:
    print("sonotheque.duckdb file already exists.")

# Create a DuckDB connection
con = duckdb.connect('./db/sonotheque.duckdb')
con.install_extension("spatial")
con.load_extension("spatial")
# Out:
# sonotheque.duckdb file already exists.

# %%
con = duckdb.connect('./db/sonotheque.duckdb')

# %%
# Aggregate records based on SON_PK and return first NOM_SCIENTIFIQUE
result = con.execute("""
    SELECT 
        SON_PK,
        FIRST(SON_UID) AS SON_UID,
        FIRST(COLLECTION_CODE) AS COLLECTION_CODE,
        FIRST(NOM_SCIENTIFIQUE) AS NOM_SCIENTIFIQUE
    FROM records
    GROUP BY SON_PK
""").fetchall()

# Display the first few results
print("Aggregated records (first 50):")
for row in result[:50]:
    print(f"SON_PK: {row[0]}, SON_UID: {row[1]}, COLLECTION_CODE: {row[2]}, NOM_SCIENTIFIQUE: {row[3]}")

# Get the total count of unique SON_PK
unique_count = con.execute("SELECT COUNT(DISTINCT SON_PK) FROM records").fetchone()[0]
print(f"\nTotal number of unique SON_PK: {unique_count}")

# %%
# Aggregate records based on SON_PK and return first NOM_SCIENTIFIQUE
result = con.execute("""
    SELECT 
        NOM_SCIENTIFIQUE,
        FIRST(SON_UID) AS SON_UID,
        FIRST(COLLECTION_CODE) AS COLLECTION_CODE,
    FROM records
    GROUP BY NOM_SCIENTIFIQUE
""").fetchall()

# Display the first few results
print("Aggregated records (first 50):")
for row in result[:50]:
    print(f"NOM_SCIENTIFIQUE: {row[0]}, SON_UID: {row[1]}, COLLECTION_CODE: {row[2]}")




# Get the total count of unique SON_PK
unique_count = con.execute("SELECT COUNT(DISTINCT NOM_SCIENTIFIQUE) FROM records").fetchone()[0]
print(f"\nTotal number of unique SON_PK: {unique_count}")

# %%
con.sql("""
    SELECT 
        NOM_SCIENTIFIQUE,
        FIRST(SON_UID) AS SON_UID,
        FIRST(COLLECTION_CODE) AS COLLECTION_CODE,
    FROM records
    GROUP BY NOM_SCIENTIFIQUE
""").show()
# Out:
# ┌──────────────────────────────────────────────────┬───────────────────────────────┬─────────────────┐
# │                 NOM_SCIENTIFIQUE                 │            SON_UID            │ COLLECTION_CODE │
# │                     varchar                      │            varchar            │     varchar     │
# ├──────────────────────────────────────────────────┼───────────────────────────────┼─────────────────┤
# │ Hyla arborea (Linnaeus, 1758)                    │ 1423750549968saMd3IX4atyu8Osf │ SO              │
# │ Gryllus campestris Linnaeus, 1758                │ 13867749528019ZTeQN2bXAkp7vVn │ SO              │
# │ Notosciobia sp affinis paranola Otte, 1987       │ 1452140705499viYCyHQU70KGgIAU │ SO              │
# │ Phonarellus minor (Chopard,1959)                 │ 1389780653418oIPwvLh4XYRHyr2V │ SO              │
# │ Cardiodactylus kondoi Otte, 2007                 │ 1431533770611Ygcat0MITMCbsJRe │ SO              │
# │ Acanthogryllus asiaticus Gorochov, 1990          │ 1467386703444ufUnTqILQLySRPZX │ SO              │
# │ Acrocephalus baeticus (Vieillot, 1817)           │ 1467988989503VajBhksOKYapYdNT │ SO              │
# │ Pirates stridulus (Fabricius, 1737)              │ 142736394288366Zuf96FjZgQZ08h │ SO              │
# │ Pixibinthus sonicus Anso & User3d, 2016          │ 14407547239319F1Mkhtta6S2oL72 │ SO              │
# │ Typhlobrixia namorokensis Synave, 1953           │ 1441099944958o8ohzxRgNQJtV83C │ SO              │
# │                ·                                 │               ·               │ ·               │
# │                ·                                 │               ·               │ ·               │
# │                ·                                 │               ·               │ ·               │
# │ Todirostrum pictum Salvin, 1897                  │ 1468364544839H7AyKQrHMirJR9qw │ SO              │
# │ Turdus fuscater d'Orbigny & Lafresnaye, 1837     │ 1468366534880wy2cL06yzjgl8fqB │ SO              │
# │ Tetraogallus caucasicus (Pallas, 1811)           │ 1468361352317iw6SbTG1mVLpVo60 │ SO              │
# │ Sylvietta rufescens (Vieillot, 1817)             │ 14683603490189uiGQxZsx5VjdPl6 │ SO              │
# │ Thalasseus sandvicensis (Latham, 1787)           │ 1468363490118JV9bP4veRlSP8RPx │ SO              │
# │ Tadorna tadorna (Linnaeus, 1758)                 │ 14683607258867gp9HvF3P2MlH63b │ SO              │
# │ Tamias sibiricus (Laxmann, 1769)                 │ 1468360804569moZHnZiF91ccBCXi │ SO              │
# │ Trogon collaris Vieillot, 1817                   │ 1468366131767kXu8zMlWk7jFq9iM │ SO              │
# │ Trogon violaceus Gmelin, JF, 1788                │ 1468366151893nqKM94gDyW9uFMs0 │ SO              │
# │ Euchrepomis spodioptila (Sclater & Salvin, 1881) │ 14683611742115AYasM7WBN3exg4T │ SO              │
# ├──────────────────────────────────────────────────┴───────────────────────────────┴─────────────────┤
# │ 1703 rows (20 shown)                                                                     3 columns │
# └────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
# con.sql("""
#     INSTALL spatial;
# LOAD spatial;
#     ALTER TABLE records
#     ADD COLUMN geometry GEOMETRY;

#     UPDATE records
#     SET geometry = ST_Point(LONGITUDE::FLOAT, LATITUDE::FLOAT)
#     WHERE LONGITUDE IS NOT NULL AND LATITUDE IS NOT NULL;
# """)


# Verify the new geometry column
con.sql("""
    SELECT 
        NOM_SCIENTIFIQUE,
        LATITUDE,
        LONGITUDE,
        ST_AsText(geometry) AS geometry_wkt
    FROM records
    WHERE geometry IS NOT NULL
    LIMIT 5
""").show()

print("\nTotal records with valid geometry:")

# %%
con.sql("SELECT COUNT(*) FROM records WHERE geometry IS NOT NULL").show()
# Out:
# ┌──────────────┐
# │ count_star() │
# │    int64     │
# ├──────────────┤
# │       202663 │
# └──────────────┘

# %%
# Aggregate records based on SON_PK and return first NOM_SCIENTIFIQUE
result = con.sql("""
    SELECT 
        uuid() AS UUID,
        NOM_SCIENTIFIQUE,
        LIST(SON_UID) AS SON_UIDS,
        FIRST(COLLECTION_CODE) AS COLLECTION_CODE,
    FROM records
    GROUP BY NOM_SCIENTIFIQUE
""")

# %%
# results_df = con.sql("""
#     SELECT 
#         uuid() AS UUID,
#         NOM_SCIENTIFIQUE,
#         LIST(SON_UID) AS SON_UIDS,
#         FIRST(COLLECTION_CODE) AS COLLECTION_CODE,
#     FROM records
#     GROUP BY NOM_SCIENTIFIQUE
# """).df()

# results_df.head()

# %%
# Add a UUID column to records and generate a UUID for each unique SON_UID value
con.sql("""
    ALTER TABLE records
    ADD COLUMN record_uuid UUID;
""")

# Generate and assign UUIDs for each unique SON_UID
con.sql("""
    WITH unique_son_uids AS (
        SELECT DISTINCT SON_UID
        FROM records
    ),
    uuid_mapping AS (
        SELECT 
            SON_UID,
            uuid() AS new_uuid
        FROM unique_son_uids
    )
    UPDATE records
    SET record_uuid = uuid_mapping.new_uuid
    FROM uuid_mapping
    WHERE records.SON_UID = uuid_mapping.SON_UID;
""")

# Verify the new column and data
print("Sample of records with new UUID column:")
con.sql("""
    SELECT 
        record_uuid,
        SON_UID,
        NOM_SCIENTIFIQUE,
        COUNT(*) OVER (PARTITION BY SON_UID) as records_per_son_uid
    FROM records
    ORDER BY SON_UID
    LIMIT 10
""").show()
# Out:
# Sample of records with new UUID column:
# ┌──────────────────────┬───────────────────────────────┬─────────────────────────────────────────┬─────────────────────┐
# │     record_uuid      │            SON_UID            │            NOM_SCIENTIFIQUE             │ records_per_son_uid │
# │         uuid         │            varchar            │                 varchar                 │        int64        │
# ├──────────────────────┼───────────────────────────────┼─────────────────────────────────────────┼─────────────────────┤
# │ c68e096d-49d0-416e…  │ 1379684303448THUEerYPSdH2oaAy │ Cicada barbara lusitanica Boulard, 1982 │                   6 │
# │ c68e096d-49d0-416e…  │ 1379684303448THUEerYPSdH2oaAy │ Cicada barbara lusitanica Boulard, 1982 │                   6 │
# │ c68e096d-49d0-416e…  │ 1379684303448THUEerYPSdH2oaAy │ Cicada barbara lusitanica Boulard, 1982 │                   6 │
# │ c68e096d-49d0-416e…  │ 1379684303448THUEerYPSdH2oaAy │ Cicada barbara lusitanica Boulard, 1982 │                   6 │
# │ c68e096d-49d0-416e…  │ 1379684303448THUEerYPSdH2oaAy │ Cicada barbara lusitanica Boulard, 1982 │                   6 │
# │ c68e096d-49d0-416e…  │ 1379684303448THUEerYPSdH2oaAy │ Cicada barbara lusitanica Boulard, 1982 │                   6 │
# │ de52a5a1-0490-4db6…  │ 1380199964961x6LFFSa28I2OPqaw │ Cicadetta brevipennis Fieber, 1876      │                   6 │
# │ de52a5a1-0490-4db6…  │ 1380199964961x6LFFSa28I2OPqaw │ Cicadetta brevipennis Fieber, 1876      │                   6 │
# │ de52a5a1-0490-4db6…  │ 1380199964961x6LFFSa28I2OPqaw │ Cicadetta brevipennis Fieber, 1876      │                   6 │
# │ de52a5a1-0490-4db6…  │ 1380199964961x6LFFSa28I2OPqaw │ Cicadetta brevipennis Fieber, 1876      │                   6 │
# ├──────────────────────┴───────────────────────────────┴─────────────────────────────────────────┴─────────────────────┤
# │ 10 rows                                                                                                    4 columns │
# └──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
#
#
# Total number of unique SON_UIDs:
# ┌─────────────────────────┐
# │ count(DISTINCT SON_UID) │
# │          int64          │
# ├─────────────────────────┤
# │                   30966 │
# └─────────────────────────┘
#
#
# Total number of records with UUID:
# ┌──────────────┐
# │ count_star() │
# │    int64     │
# ├──────────────┤
# │       227491 │
# └──────────────┘

# %%
print("\nTotal number of unique SON_UIDs:")
con.sql("SELECT COUNT(DISTINCT SON_UID) FROM records").show()

print("\nTotal number of records with UUID:")
con.sql("SELECT COUNT(DISTINCT record_uuid) FROM records").show()
# Out:
# Total number of unique SON_UIDs:
# ┌─────────────────────────┐
# │ count(DISTINCT SON_UID) │
# │          int64          │
# ├─────────────────────────┤
# │                   30966 │
# └─────────────────────────┘
#
#
# Total number of records with UUID:
# ┌─────────────────────────────┐
# │ count(DISTINCT record_uuid) │
# │            int64            │
# ├─────────────────────────────┤
# │                       30966 │
# └─────────────────────────────┘

# %%
# Aggregate records based on SON_PK and return first NOM_SCIENTIFIQUE
results_df = con.sql("""
    SELECT 
        uuid() AS UUID,
        NOM_SCIENTIFIQUE,
        LIST(SON_UID) AS SON_UIDS,
        FIRST(COLLECTION_CODE) AS COLLECTION_CODE,
    FROM records
    GROUP BY NOM_SCIENTIFIQUE
""").df()

# %%
import ibis
from ibis import _

ibis.options.interactive = True

con = ibis.duckdb.connect('./db/sonotheque.duckdb')
con.list_tables()
# Out:
# ['import_records', 'records']

# %%
con.load_extension("spatial")
records = con.table("records")

# %%
records.rename("snake_case")
# Out:
# ┏━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ son_pk ┃ son_uid                       ┃ type   ┃ titre                                     ┃ institution_code ┃ collection_code ┃ catalog_number ┃ valide ┃ valide_par ┃ publie ┃ date_publication_debut ┃ date_publication_fin ┃ publication_scientifique                                                         ┃ recorder                        ┃ micro        ┃ parabole ┃ frequence_echantillonnage ┃ support_original ┃ qualite ┃ date_enregistrement_int ┃ heure_enregistrement_int ┃ lieu_enregistrement ┃ temperature ┃ commentaires_enregistrement ┃ contexte_comportemental          ┃ habitat ┃ description_habitat ┃ continent_ocean ┃ pays             ┃ localite                                             ┃ latitude  ┃ longitude ┃ altitude ┃ commentaires                                ┃ datecre             ┃ datemaj             ┃ usercre ┃ usermaj ┃ telecharger_wav ┃ degre_certitude ┃ luminosite ┃ droits      ┃ son_mode_identification_pk ┃ son_fk ┃ mode_identification ┃ vocabulaire_pk ┃ vocabulaire_categorie_fk ┃ libelle_fr        ┃ libelle_en        ┃ old_pk ┃ datecre2            ┃ datemaj3            ┃ usercre4 ┃ usermaj5 ┃ son_espece_pk ┃ son_fk6 ┃ espece_fk ┃ degre_certitude7 ┃ datecre8            ┃ datemaj9            ┃ usercre10 ┃ usermaj11 ┃ espece_pk ┃ valide12 ┃ groupe_taxonomique ┃ ordre      ┃ famille        ┃ genre       ┃ epithete_specifique ┃ epithete_infra_specifique ┃ descripteur               ┃ nom_scientifique                              ┃ datecre13           ┃ datemaj14           ┃ usercre15 ┃ usermaj16 ┃ nom_vernaculaire_pk ┃ espece_fk17 ┃ lang   ┃ nom                      ┃ datecre18           ┃ datemaj19           ┃ usercre20 ┃ usermaj21 ┃ vocabulaire_pk22 ┃ vocabulaire_categorie_fk23 ┃ libelle_fr24 ┃ libelle_en25 ┃ old_pk26 ┃ datecre27           ┃ datemaj28           ┃ usercre29 ┃ usermaj30 ┃ son_auteur_pk ┃ son_fk31 ┃ auteur_fk ┃ datecre32           ┃ datemaj33           ┃ usercre34 ┃ usermaj35 ┃ auteur_pk ┃ nom36  ┃ datecre37           ┃ datemaj38           ┃ usercre39 ┃ usermaj40 ┃ son_mot_cle_pk ┃ son_fk41 ┃ mot_cle_fk ┃ datecre42    ┃ datemaj43    ┃ usercre44 ┃ usermaj45 ┃ mot_cle_pk ┃ lang46 ┃ libelle ┃ datecre47    ┃ datemaj48    ┃ usercre49 ┃ usermaj50 ┃ son_specimen_pk ┃ son_fk51 ┃ specimen_fk ┃ datecre52    ┃ datemaj53    ┃ usercre54 ┃ usermaj55 ┃ specimen_pk ┃ institution_code56 ┃ collection_code57 ┃ catalog_number58 ┃ date_collecte_int ┃ heure_collecte_int ┃ luminosite59 ┃ collecteur ┃ datecre60    ┃ datemaj61    ┃ usercre62 ┃ usermaj63 ┃ fichier_son_pk ┃ son_fk64 ┃ fichier_uid                   ┃ type65 ┃ path                        ┃ filename                          ┃ mime_type  ┃ taille ┃ checksum   ┃ duree  ┃ bitspersample ┃ channels ┃ frequence_echantillonnage66 ┃ datecre67           ┃ datemaj68           ┃ usercre69 ┃ usermaj70 ┃ son_image_pk ┃ son_fk71 ┃ image_fk ┃ type72      ┃ datecre73           ┃ datemaj74           ┃ usercre75 ┃ usermaj76 ┃ image_pk ┃ image_uid                     ┃ id      ┃ mime_type77 ┃ modele ┃ taille78 ┃ checksum79 ┃ largeur ┃ hauteur ┃ credit  ┃ datecre80           ┃ datemaj81           ┃ usercre82 ┃ usermaj83 ┃ geometry               ┃ record_uuid                          ┃
# ┡━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ int64  │ string                        │ string │ string                                    │ string           │ string          │ string         │ int64  │ string     │ int64  │ timestamp(6)           │ timestamp(6)         │ string                                                                           │ string                          │ string       │ int64    │ int64                     │ int64            │ int64   │ int64                   │ int64                    │ int64               │ string      │ string                      │ string                           │ string  │ string              │ string          │ string           │ string                                               │ float64   │ float64   │ int64    │ string                                      │ timestamp(6)        │ timestamp(6)        │ string  │ string  │ int64           │ int64           │ int64      │ string      │ int64                      │ int64  │ int64               │ int64          │ int64                    │ string            │ string            │ int64  │ timestamp(6)        │ timestamp(6)        │ string   │ string   │ int64         │ int64   │ int64     │ int64            │ timestamp(6)        │ timestamp(6)        │ string    │ string    │ int64     │ int64    │ int64              │ string     │ string         │ string      │ string              │ string                    │ string                    │ string                                        │ timestamp(6)        │ timestamp(6)        │ string    │ string    │ int64               │ int64       │ string │ string                   │ timestamp(6)        │ timestamp(6)        │ string    │ string    │ int64            │ int64                      │ string       │ string       │ int64    │ timestamp(6)        │ timestamp(6)        │ string    │ string    │ int64         │ int64    │ int64     │ timestamp(6)        │ timestamp(6)        │ string    │ string    │ int64     │ string │ timestamp(6)        │ timestamp(6)        │ string    │ string    │ int64          │ int64    │ int64      │ timestamp(6) │ timestamp(6) │ string    │ string    │ int64      │ string │ string  │ timestamp(6) │ timestamp(6) │ string    │ string    │ int64           │ int64    │ int64       │ timestamp(6) │ timestamp(6) │ string    │ string    │ int64       │ string             │ string            │ string           │ int64             │ int64              │ int64        │ string     │ timestamp(6) │ timestamp(6) │ string    │ string    │ int64          │ int64    │ string                        │ string │ string                      │ string                            │ string     │ int64  │ int64      │ string │ int64         │ int64    │ int64                       │ timestamp(6)        │ timestamp(6)        │ string    │ string    │ int64        │ int64    │ int64    │ string      │ timestamp(6)        │ timestamp(6)        │ string    │ string    │ int64    │ string                        │ string  │ string      │ int64  │ int64    │ int64      │ int64   │ int64   │ string  │ timestamp(6)        │ timestamp(6)        │ string    │ string    │ geospatial:geometry    │ uuid                                 │
# ├────────┼───────────────────────────────┼────────┼───────────────────────────────────────────┼──────────────────┼─────────────────┼────────────────┼────────┼────────────┼────────┼────────────────────────┼──────────────────────┼──────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────┼──────────────┼──────────┼───────────────────────────┼──────────────────┼─────────┼─────────────────────────┼──────────────────────────┼─────────────────────┼─────────────┼─────────────────────────────┼──────────────────────────────────┼─────────┼─────────────────────┼─────────────────┼──────────────────┼──────────────────────────────────────────────────────┼───────────┼───────────┼──────────┼─────────────────────────────────────────────┼─────────────────────┼─────────────────────┼─────────┼─────────┼─────────────────┼─────────────────┼────────────┼─────────────┼────────────────────────────┼────────┼─────────────────────┼────────────────┼──────────────────────────┼───────────────────┼───────────────────┼────────┼─────────────────────┼─────────────────────┼──────────┼──────────┼───────────────┼─────────┼───────────┼──────────────────┼─────────────────────┼─────────────────────┼───────────┼───────────┼───────────┼──────────┼────────────────────┼────────────┼────────────────┼─────────────┼─────────────────────┼───────────────────────────┼───────────────────────────┼───────────────────────────────────────────────┼─────────────────────┼─────────────────────┼───────────┼───────────┼─────────────────────┼─────────────┼────────┼──────────────────────────┼─────────────────────┼─────────────────────┼───────────┼───────────┼──────────────────┼────────────────────────────┼──────────────┼──────────────┼──────────┼─────────────────────┼─────────────────────┼───────────┼───────────┼───────────────┼──────────┼───────────┼─────────────────────┼─────────────────────┼───────────┼───────────┼───────────┼────────┼─────────────────────┼─────────────────────┼───────────┼───────────┼────────────────┼──────────┼────────────┼──────────────┼──────────────┼───────────┼───────────┼────────────┼────────┼─────────┼──────────────┼──────────────┼───────────┼───────────┼─────────────────┼──────────┼─────────────┼──────────────┼──────────────┼───────────┼───────────┼─────────────┼────────────────────┼───────────────────┼──────────────────┼───────────────────┼────────────────────┼──────────────┼────────────┼──────────────┼──────────────┼───────────┼───────────┼────────────────┼──────────┼───────────────────────────────┼────────┼─────────────────────────────┼───────────────────────────────────┼────────────┼────────┼────────────┼────────┼───────────────┼──────────┼─────────────────────────────┼─────────────────────┼─────────────────────┼───────────┼───────────┼──────────────┼──────────┼──────────┼─────────────┼─────────────────────┼─────────────────────┼───────────┼───────────┼──────────┼───────────────────────────────┼─────────┼─────────────┼────────┼──────────┼────────────┼─────────┼─────────┼─────────┼─────────────────────┼─────────────────────┼───────────┼───────────┼────────────────────────┼──────────────────────────────────────┤
# │    330 │ 138070607836168Xe2DOmqTZSKXOU │ ESPECE │ Grillon Luzaridella obscura chant d'appel │ MNHN             │ SO              │ 2014-330       │      0 │ NULL       │      1 │ 2013-10-03 00:00:00    │ NULL                 │ Desutter-Grandcolas, L. 1992, Bulletin du Muséum national d'Histoire naturelle,… │ Sony recorder WM-DC6            │ ECM929       │        0 │                         0 │               14 │       4 │                 1018035 │                       94 │                NULL │ 23          │ [NULL]                      │ Chant d'appel.\r\nSemi-captivité │ NULL    │ [NULL]              │ Amérique        │ Guyane française │ Arataye, affl. Approuagues, 8 km NE pied saut Parare │      NULL │      NULL │     NULL │ [NULL]                                      │ 2013-10-02 11:27:58 │ 2016-02-26 18:01:22 │ User2   │ User2   │               0 │             100 │          0 │ cc-by-nc-nd │                       3558 │    330 │                  10 │             10 │                        2 │ Etude du spécimen │ Etude du spécimen │     11 │ 2016-06-17 10:33:02 │ 2016-06-17 10:33:02 │ admin    │ admin    │           105 │     330 │        64 │              100 │ 2013-10-02 11:27:58 │ 2016-02-26 18:01:22 │ User2     │ User2     │        64 │        1 │                  1 │ Orthoptera │ Phalangopsidae │ Luzaridella │ obscura             │ NULL                      │ Desutter-Grandcolas, 1992 │ Luzaridella obscura Desutter-Grandcolas, 1992 │ 2013-10-02 11:19:21 │ 2017-01-18 10:13:22 │ User2     │ User1     │                NULL │        NULL │ NULL   │ NULL                     │ NULL                │ NULL                │ NULL      │ NULL      │                1 │                          1 │ Insectes     │ Insects      │        1 │ 2016-06-17 10:33:02 │ 2016-06-17 10:33:02 │ admin     │ admin     │           105 │      330 │        13 │ 2013-10-02 11:27:58 │ 2016-02-26 18:01:22 │ User2     │ User2     │        13 │ User2  │ 2013-10-02 15:40:15 │ 2016-02-26 17:47:39 │ User2     │ User2     │           NULL │     NULL │       NULL │ NULL         │ NULL         │ NULL      │ NULL      │       NULL │ NULL   │ NULL    │ NULL         │ NULL         │ NULL      │ NULL      │            NULL │     NULL │        NULL │ NULL         │ NULL         │ NULL      │ NULL      │        NULL │ NULL               │ NULL              │ NULL             │              NULL │               NULL │         NULL │ NULL       │ NULL         │ NULL         │ NULL      │ NULL      │            171 │      330 │ 138070610403976zVnynBeWnWh7lT │ MP3    │ 2013/10/02/MNHN_SO_2014-330 │ 138070610403976zVnynBeWnWh7lT.mp3 │ audio/mpeg │ 945127 │ 3117388173 │ NULL   │            16 │        1 │                           0 │ 2013-10-02 11:27:58 │ 2016-02-26 18:01:22 │ User2     │ User2     │          227 │      330 │        9 │ VIGNETTE    │ 2013-10-02 11:27:58 │ 2016-02-26 18:01:22 │ User2     │ User2     │        9 │ 1466155938028Ys4MWYthQnHM92SL │ Grillon │ image/png   │      1 │    36233 │ 2735274658 │     800 │     450 │ NULL    │ 2016-06-17 11:32:18 │ 2016-06-23 10:34:20 │ admin     │ User8     │ NULL                   │ 8c839fa0-52a6-4998-9732-e22bbfb1eeec │
# │    441 │ 13867749528019ZTeQN2bXAkp7vVn │ ESPECE │ Gryllus campestris                        │ MNHN             │ SO              │ 2014-441       │      1 │ NULL       │      1 │ 2016-06-30 00:00:00    │ NULL                 │ [NULL]                                                                           │ Avisoft recorder-carte son Motu │ CM16 Avisoft │        0 │                     96000 │               16 │       5 │                 1030852 │                       -1 │                  18 │ 26          │ [NULL]                      │ appel - male isolé               │ NULL    │ [NULL]              │ Europe          │ France           │ Grenoble                                             │ 45.183586 │  5.676636 │     NULL │ Nombreux autres enregistrements disponibles │ 2013-12-11 16:15:52 │ 2020-05-18 22:02:11 │ User3   │ User1   │               0 │             100 │          0 │ cc-by-nc-nd │                       9311 │    441 │                  10 │             10 │                        2 │ Etude du spécimen │ Etude du spécimen │     11 │ 2016-06-17 10:33:02 │ 2016-06-17 10:33:02 │ admin    │ admin    │           106 │     441 │        65 │              100 │ 2013-12-11 16:15:52 │ 2016-02-09 18:36:42 │ User3     │ User3     │        65 │        1 │                  1 │ Orthoptera │ Gryllidae      │ Gryllus     │ campestris          │ NULL                      │ Linnaeus, 1758            │ Gryllus campestris Linnaeus, 1758             │ 2013-12-11 16:15:52 │ 2017-01-17 12:48:53 │ User3     │ User1     │                1880 │          65 │ NULL   │ Grillon champêtre        │ 2017-01-17 12:48:53 │ 2017-01-17 12:48:53 │ User1     │ User1     │                1 │                          1 │ Insectes     │ Insects      │        1 │ 2016-06-17 10:33:02 │ 2016-06-17 10:33:02 │ admin     │ admin     │           106 │      441 │         7 │ 2013-12-11 16:15:52 │ 2016-02-09 18:36:42 │ User3     │ User3     │         7 │ User3  │ 2013-10-04 11:47:02 │ 2016-02-09 13:57:35 │ User1     │ User3     │           NULL │     NULL │       NULL │ NULL         │ NULL         │ NULL      │ NULL      │       NULL │ NULL   │ NULL    │ NULL         │ NULL         │ NULL      │ NULL      │            NULL │     NULL │        NULL │ NULL         │ NULL         │ NULL      │ NULL      │        NULL │ NULL               │ NULL              │ NULL             │              NULL │               NULL │         NULL │ NULL       │ NULL         │ NULL         │ NULL      │ NULL      │            173 │      441 │ 1453824248000YEjjaaH69KxXmDEj │ MP3    │ 2016/01/26/MNHN_SO_2014-441 │ 1453824248000YEjjaaH69KxXmDEj.mp3 │ audio/mpeg │ 478848 │  885809208 │ NULL   │            16 │        1 │                       96000 │ 2013-12-11 16:15:52 │ 2016-02-09 18:36:42 │ User3     │ User3     │          230 │      441 │      193 │ WAVEFORM    │ 2016-06-20 18:10:09 │ 2016-06-20 18:10:09 │ User3     │ User3     │      193 │ 1466439009826Fdd0z6K3bwCozrUT │ NULL    │ image/png   │      0 │     2399 │ 2147270256 │     800 │     450 │ NULL    │ 2016-06-20 18:10:09 │ 2016-06-20 18:10:09 │ User3     │ User3     │ <POINT (5.677 45.184)> │ 2fcdad52-c712-4e92-9ad8-4e58b7c80336 │
# │    441 │ 13867749528019ZTeQN2bXAkp7vVn │ ESPECE │ Gryllus campestris                        │ MNHN             │ SO              │ 2014-441       │      1 │ NULL       │      1 │ 2016-06-30 00:00:00    │ NULL                 │ [NULL]                                                                           │ Avisoft recorder-carte son Motu │ CM16 Avisoft │        0 │                     96000 │               16 │       5 │                 1030852 │                       -1 │                  18 │ 26          │ [NULL]                      │ appel - male isolé               │ NULL    │ [NULL]              │ Europe          │ France           │ Grenoble                                             │ 45.183586 │  5.676636 │     NULL │ Nombreux autres enregistrements disponibles │ 2013-12-11 16:15:52 │ 2020-05-18 22:02:11 │ User3   │ User1   │               0 │             100 │          0 │ cc-by-nc-nd │                       9311 │    441 │                  10 │             10 │                        2 │ Etude du spécimen │ Etude du spécimen │     11 │ 2016-06-17 10:33:02 │ 2016-06-17 10:33:02 │ admin    │ admin    │           106 │     441 │        65 │              100 │ 2013-12-11 16:15:52 │ 2016-02-09 18:36:42 │ User3     │ User3     │        65 │        1 │                  1 │ Orthoptera │ Gryllidae      │ Gryllus     │ campestris          │ NULL                      │ Linnaeus, 1758            │ Gryllus campestris Linnaeus, 1758             │ 2013-12-11 16:15:52 │ 2017-01-17 12:48:53 │ User3     │ User1     │                1879 │          65 │ NULL   │ Petit Cheval du Bon Dieu │ 2017-01-17 12:48:53 │ 2017-01-17 12:48:53 │ User1     │ User1     │                1 │                          1 │ Insectes     │ Insects      │        1 │ 2016-06-17 10:33:02 │ 2016-06-17 10:33:02 │ admin     │ admin     │           106 │      441 │         7 │ 2013-12-11 16:15:52 │ 2016-02-09 18:36:42 │ User3     │ User3     │         7 │ User3  │ 2013-10-04 11:47:02 │ 2016-02-09 13:57:35 │ User1     │ User3     │           NULL │     NULL │       NULL │ NULL         │ NULL         │ NULL      │ NULL      │       NULL │ NULL   │ NULL    │ NULL         │ NULL         │ NULL      │ NULL      │            NULL │     NULL │        NULL │ NULL         │ NULL         │ NULL      │ NULL      │        NULL │ NULL               │ NULL              │ NULL             │              NULL │               NULL │         NULL │ NULL       │ NULL         │ NULL         │ NULL      │ NULL      │            173 │      441 │ 1453824248000YEjjaaH69KxXmDEj │ MP3    │ 2016/01/26/MNHN_SO_2014-441 │ 1453824248000YEjjaaH69KxXmDEj.mp3 │ audio/mpeg │ 478848 │  885809208 │ NULL   │            16 │        1 │                       96000 │ 2013-12-11 16:15:52 │ 2016-02-09 18:36:42 │ User3     │ User3     │          230 │      441 │      193 │ WAVEFORM    │ 2016-06-20 18:10:09 │ 2016-06-20 18:10:09 │ User3     │ User3     │      193 │ 1466439009826Fdd0z6K3bwCozrUT │ NULL    │ image/png   │      0 │     2399 │ 2147270256 │     800 │     450 │ NULL    │ 2016-06-20 18:10:09 │ 2016-06-20 18:10:09 │ User3     │ User3     │ <POINT (5.677 45.184)> │ 2fcdad52-c712-4e92-9ad8-4e58b7c80336 │
# │    441 │ 13867749528019ZTeQN2bXAkp7vVn │ ESPECE │ Gryllus campestris                        │ MNHN             │ SO              │ 2014-441       │      1 │ NULL       │      1 │ 2016-06-30 00:00:00    │ NULL                 │ [NULL]                                                                           │ Avisoft recorder-carte son Motu │ CM16 Avisoft │        0 │                     96000 │               16 │       5 │                 1030852 │                       -1 │                  18 │ 26          │ [NULL]                      │ appel - male isolé               │ NULL    │ [NULL]              │ Europe          │ France           │ Grenoble                                             │ 45.183586 │  5.676636 │     NULL │ Nombreux autres enregistrements disponibles │ 2013-12-11 16:15:52 │ 2020-05-18 22:02:11 │ User3   │ User1   │               0 │             100 │          0 │ cc-by-nc-nd │                       9311 │    441 │                  10 │             10 │                        2 │ Etude du spécimen │ Etude du spécimen │     11 │ 2016-06-17 10:33:02 │ 2016-06-17 10:33:02 │ admin    │ admin    │           106 │     441 │        65 │              100 │ 2013-12-11 16:15:52 │ 2016-02-09 18:36:42 │ User3     │ User3     │        65 │        1 │                  1 │ Orthoptera │ Gryllidae      │ Gryllus     │ campestris          │ NULL                      │ Linnaeus, 1758            │ Gryllus campestris Linnaeus, 1758             │ 2013-12-11 16:15:52 │ 2017-01-17 12:48:53 │ User3     │ User1     │                1882 │          65 │ NULL   │ Grillon sauvage          │ 2017-01-17 12:48:53 │ 2017-01-17 12:48:53 │ User1     │ User1     │                1 │                          1 │ Insectes     │ Insects      │        1 │ 2016-06-17 10:33:02 │ 2016-06-17 10:33:02 │ admin     │ admin     │           106 │      441 │         7 │ 2013-12-11 16:15:52 │ 2016-02-09 18:36:42 │ User3     │ User3     │         7 │ User3  │ 2013-10-04 11:47:02 │ 2016-02-09 13:57:35 │ User1     │ User3     │           NULL │     NULL │       NULL │ NULL         │ NULL         │ NULL      │ NULL      │       NULL │ NULL   │ NULL    │ NULL         │ NULL         │ NULL      │ NULL      │            NULL │     NULL │        NULL │ NULL         │ NULL         │ NULL      │ NULL      │        NULL │ NULL               │ NULL              │ NULL             │              NULL │               NULL │         NULL │ NULL       │ NULL         │ NULL         │ NULL      │ NULL      │            173 │      441 │ 1453824248000YEjjaaH69KxXmDEj │ MP3    │ 2016/01/26/MNHN_SO_2014-441 │ 1453824248000YEjjaaH69KxXmDEj.mp3 │ audio/mpeg │ 478848 │  885809208 │ NULL   │            16 │        1 │                       96000 │ 2013-12-11 16:15:52 │ 2016-02-09 18:36:42 │ User3     │ User3     │          230 │      441 │      193 │ WAVEFORM    │ 2016-06-20 18:10:09 │ 2016-06-20 18:10:09 │ User3     │ User3     │      193 │ 1466439009826Fdd0z6K3bwCozrUT │ NULL    │ image/png   │      0 │     2399 │ 2147270256 │     800 │     450 │ NULL    │ 2016-06-20 18:10:09 │ 2016-06-20 18:10:09 │ User3     │ User3     │ <POINT (5.677 45.184)> │ 2fcdad52-c712-4e92-9ad8-4e58b7c80336 │
# │    441 │ 13867749528019ZTeQN2bXAkp7vVn │ ESPECE │ Gryllus campestris                        │ MNHN             │ SO              │ 2014-441       │      1 │ NULL       │      1 │ 2016-06-30 00:00:00    │ NULL                 │ [NULL]                                                                           │ Avisoft recorder-carte son Motu │ CM16 Avisoft │        0 │                     96000 │               16 │       5 │                 1030852 │                       -1 │                  18 │ 26          │ [NULL]                      │ appel - male isolé               │ NULL    │ [NULL]              │ Europe          │ France           │ Grenoble                                             │ 45.183586 │  5.676636 │     NULL │ Nombreux autres enregistrements disponibles │ 2013-12-11 16:15:52 │ 2020-05-18 22:02:11 │ User3   │ User1   │               0 │             100 │          0 │ cc-by-nc-nd │                       9311 │    441 │                  10 │             10 │                        2 │ Etude du spécimen │ Etude du spécimen │     11 │ 2016-06-17 10:33:02 │ 2016-06-17 10:33:02 │ admin    │ admin    │           106 │     441 │        65 │              100 │ 2013-12-11 16:15:52 │ 2016-02-09 18:36:42 │ User3     │ User3     │        65 │        1 │                  1 │ Orthoptera │ Gryllidae      │ Gryllus     │ campestris          │ NULL                      │ Linnaeus, 1758            │ Gryllus campestris Linnaeus, 1758             │ 2013-12-11 16:15:52 │ 2017-01-17 12:48:53 │ User3     │ User1     │                1881 │          65 │ NULL   │ Grillon des champs       │ 2017-01-17 12:48:53 │ 2017-01-17 12:48:53 │ User1     │ User1     │                1 │                          1 │ Insectes     │ Insects      │        1 │ 2016-06-17 10:33:02 │ 2016-06-17 10:33:02 │ admin     │ admin     │           106 │      441 │         7 │ 2013-12-11 16:15:52 │ 2016-02-09 18:36:42 │ User3     │ User3     │         7 │ User3  │ 2013-10-04 11:47:02 │ 2016-02-09 13:57:35 │ User1     │ User3     │           NULL │     NULL │       NULL │ NULL         │ NULL         │ NULL      │ NULL      │       NULL │ NULL   │ NULL    │ NULL         │ NULL         │ NULL      │ NULL      │            NULL │     NULL │        NULL │ NULL         │ NULL         │ NULL      │ NULL      │        NULL │ NULL               │ NULL              │ NULL             │              NULL │               NULL │         NULL │ NULL       │ NULL         │ NULL         │ NULL      │ NULL      │            173 │      441 │ 1453824248000YEjjaaH69KxXmDEj │ MP3    │ 2016/01/26/MNHN_SO_2014-441 │ 1453824248000YEjjaaH69KxXmDEj.mp3 │ audio/mpeg │ 478848 │  885809208 │ NULL   │            16 │        1 │                       96000 │ 2013-12-11 16:15:52 │ 2016-02-09 18:36:42 │ User3     │ User3     │          230 │      441 │      193 │ WAVEFORM    │ 2016-06-20 18:10:09 │ 2016-06-20 18:10:09 │ User3     │ User3     │      193 │ 1466439009826Fdd0z6K3bwCozrUT │ NULL    │ image/png   │      0 │     2399 │ 2147270256 │     800 │     450 │ NULL    │ 2016-06-20 18:10:09 │ 2016-06-20 18:10:09 │ User3     │ User3     │ <POINT (5.677 45.184)> │ 2fcdad52-c712-4e92-9ad8-4e58b7c80336 │
# │    441 │ 13867749528019ZTeQN2bXAkp7vVn │ ESPECE │ Gryllus campestris                        │ MNHN             │ SO              │ 2014-441       │      1 │ NULL       │      1 │ 2016-06-30 00:00:00    │ NULL                 │ [NULL]                                                                           │ Avisoft recorder-carte son Motu │ CM16 Avisoft │        0 │                     96000 │               16 │       5 │                 1030852 │                       -1 │                  18 │ 26          │ [NULL]                      │ appel - male isolé               │ NULL    │ [NULL]              │ Europe          │ France           │ Grenoble                                             │ 45.183586 │  5.676636 │     NULL │ Nombreux autres enregistrements disponibles │ 2013-12-11 16:15:52 │ 2020-05-18 22:02:11 │ User3   │ User1   │               0 │             100 │          0 │ cc-by-nc-nd │                       9311 │    441 │                  10 │             10 │                        2 │ Etude du spécimen │ Etude du spécimen │     11 │ 2016-06-17 10:33:02 │ 2016-06-17 10:33:02 │ admin    │ admin    │           106 │     441 │        65 │              100 │ 2013-12-11 16:15:52 │ 2016-02-09 18:36:42 │ User3     │ User3     │        65 │        1 │                  1 │ Orthoptera │ Gryllidae      │ Gryllus     │ campestris          │ NULL                      │ Linnaeus, 1758            │ Gryllus campestris Linnaeus, 1758             │ 2013-12-11 16:15:52 │ 2017-01-17 12:48:53 │ User3     │ User1     │                1880 │          65 │ NULL   │ Grillon champêtre        │ 2017-01-17 12:48:53 │ 2017-01-17 12:48:53 │ User1     │ User1     │                1 │                          1 │ Insectes     │ Insects      │        1 │ 2016-06-17 10:33:02 │ 2016-06-17 10:33:02 │ admin     │ admin     │           106 │      441 │         7 │ 2013-12-11 16:15:52 │ 2016-02-09 18:36:42 │ User3     │ User3     │         7 │ User3  │ 2013-10-04 11:47:02 │ 2016-02-09 13:57:35 │ User1     │ User3     │           NULL │     NULL │       NULL │ NULL         │ NULL         │ NULL      │ NULL      │       NULL │ NULL   │ NULL    │ NULL         │ NULL         │ NULL      │ NULL      │            NULL │     NULL │        NULL │ NULL         │ NULL         │ NULL      │ NULL      │        NULL │ NULL               │ NULL              │ NULL             │              NULL │               NULL │         NULL │ NULL       │ NULL         │ NULL         │ NULL      │ NULL      │            173 │      441 │ 1453824248000YEjjaaH69KxXmDEj │ MP3    │ 2016/01/26/MNHN_SO_2014-441 │ 1453824248000YEjjaaH69KxXmDEj.mp3 │ audio/mpeg │ 478848 │  885809208 │ NULL   │            16 │        1 │                       96000 │ 2013-12-11 16:15:52 │ 2016-02-09 18:36:42 │ User3     │ User3     │          229 │      441 │      192 │ SPECTROGRAM │ 2016-06-20 18:10:09 │ 2016-06-20 18:10:09 │ User3     │ User3     │      192 │ 1466439009512o5iSPsZICAY7T8GR │ NULL    │ image/png   │      0 │   417860 │ 2276365895 │    1048 │     578 │ NULL    │ 2016-06-20 18:10:09 │ 2016-06-20 18:10:09 │ User3     │ User3     │ <POINT (5.677 45.184)> │ 2fcdad52-c712-4e92-9ad8-4e58b7c80336 │
# │    441 │ 13867749528019ZTeQN2bXAkp7vVn │ ESPECE │ Gryllus campestris                        │ MNHN             │ SO              │ 2014-441       │      1 │ NULL       │      1 │ 2016-06-30 00:00:00    │ NULL                 │ [NULL]                                                                           │ Avisoft recorder-carte son Motu │ CM16 Avisoft │        0 │                     96000 │               16 │       5 │                 1030852 │                       -1 │                  18 │ 26          │ [NULL]                      │ appel - male isolé               │ NULL    │ [NULL]              │ Europe          │ France           │ Grenoble                                             │ 45.183586 │  5.676636 │     NULL │ Nombreux autres enregistrements disponibles │ 2013-12-11 16:15:52 │ 2020-05-18 22:02:11 │ User3   │ User1   │               0 │             100 │          0 │ cc-by-nc-nd │                       9311 │    441 │                  10 │             10 │                        2 │ Etude du spécimen │ Etude du spécimen │     11 │ 2016-06-17 10:33:02 │ 2016-06-17 10:33:02 │ admin    │ admin    │           106 │     441 │        65 │              100 │ 2013-12-11 16:15:52 │ 2016-02-09 18:36:42 │ User3     │ User3     │        65 │        1 │                  1 │ Orthoptera │ Gryllidae      │ Gryllus     │ campestris          │ NULL                      │ Linnaeus, 1758            │ Gryllus campestris Linnaeus, 1758             │ 2013-12-11 16:15:52 │ 2017-01-17 12:48:53 │ User3     │ User1     │                1879 │          65 │ NULL   │ Petit Cheval du Bon Dieu │ 2017-01-17 12:48:53 │ 2017-01-17 12:48:53 │ User1     │ User1     │                1 │                          1 │ Insectes     │ Insects      │        1 │ 2016-06-17 10:33:02 │ 2016-06-17 10:33:02 │ admin     │ admin     │           106 │      441 │         7 │ 2013-12-11 16:15:52 │ 2016-02-09 18:36:42 │ User3     │ User3     │         7 │ User3  │ 2013-10-04 11:47:02 │ 2016-02-09 13:57:35 │ User1     │ User3     │           NULL │     NULL │       NULL │ NULL         │ NULL         │ NULL      │ NULL      │       NULL │ NULL   │ NULL    │ NULL         │ NULL         │ NULL      │ NULL      │            NULL │     NULL │        NULL │ NULL         │ NULL         │ NULL      │ NULL      │        NULL │ NULL               │ NULL              │ NULL             │              NULL │               NULL │         NULL │ NULL       │ NULL         │ NULL         │ NULL      │ NULL      │            173 │      441 │ 1453824248000YEjjaaH69KxXmDEj │ MP3    │ 2016/01/26/MNHN_SO_2014-441 │ 1453824248000YEjjaaH69KxXmDEj.mp3 │ audio/mpeg │ 478848 │  885809208 │ NULL   │            16 │        1 │                       96000 │ 2013-12-11 16:15:52 │ 2016-02-09 18:36:42 │ User3     │ User3     │          229 │      441 │      192 │ SPECTROGRAM │ 2016-06-20 18:10:09 │ 2016-06-20 18:10:09 │ User3     │ User3     │      192 │ 1466439009512o5iSPsZICAY7T8GR │ NULL    │ image/png   │      0 │   417860 │ 2276365895 │    1048 │     578 │ NULL    │ 2016-06-20 18:10:09 │ 2016-06-20 18:10:09 │ User3     │ User3     │ <POINT (5.677 45.184)> │ 2fcdad52-c712-4e92-9ad8-4e58b7c80336 │
# │    441 │ 13867749528019ZTeQN2bXAkp7vVn │ ESPECE │ Gryllus campestris                        │ MNHN             │ SO              │ 2014-441       │      1 │ NULL       │      1 │ 2016-06-30 00:00:00    │ NULL                 │ [NULL]                                                                           │ Avisoft recorder-carte son Motu │ CM16 Avisoft │        0 │                     96000 │               16 │       5 │                 1030852 │                       -1 │                  18 │ 26          │ [NULL]                      │ appel - male isolé               │ NULL    │ [NULL]              │ Europe          │ France           │ Grenoble                                             │ 45.183586 │  5.676636 │     NULL │ Nombreux autres enregistrements disponibles │ 2013-12-11 16:15:52 │ 2020-05-18 22:02:11 │ User3   │ User1   │               0 │             100 │          0 │ cc-by-nc-nd │                       9311 │    441 │                  10 │             10 │                        2 │ Etude du spécimen │ Etude du spécimen │     11 │ 2016-06-17 10:33:02 │ 2016-06-17 10:33:02 │ admin    │ admin    │           106 │     441 │        65 │              100 │ 2013-12-11 16:15:52 │ 2016-02-09 18:36:42 │ User3     │ User3     │        65 │        1 │                  1 │ Orthoptera │ Gryllidae      │ Gryllus     │ campestris          │ NULL                      │ Linnaeus, 1758            │ Gryllus campestris Linnaeus, 1758             │ 2013-12-11 16:15:52 │ 2017-01-17 12:48:53 │ User3     │ User1     │                1882 │          65 │ NULL   │ Grillon sauvage          │ 2017-01-17 12:48:53 │ 2017-01-17 12:48:53 │ User1     │ User1     │                1 │                          1 │ Insectes     │ Insects      │        1 │ 2016-06-17 10:33:02 │ 2016-06-17 10:33:02 │ admin     │ admin     │           106 │      441 │         7 │ 2013-12-11 16:15:52 │ 2016-02-09 18:36:42 │ User3     │ User3     │         7 │ User3  │ 2013-10-04 11:47:02 │ 2016-02-09 13:57:35 │ User1     │ User3     │           NULL │     NULL │       NULL │ NULL         │ NULL         │ NULL      │ NULL      │       NULL │ NULL   │ NULL    │ NULL         │ NULL         │ NULL      │ NULL      │            NULL │     NULL │        NULL │ NULL         │ NULL         │ NULL      │ NULL      │        NULL │ NULL               │ NULL              │ NULL             │              NULL │               NULL │         NULL │ NULL       │ NULL         │ NULL         │ NULL      │ NULL      │            173 │      441 │ 1453824248000YEjjaaH69KxXmDEj │ MP3    │ 2016/01/26/MNHN_SO_2014-441 │ 1453824248000YEjjaaH69KxXmDEj.mp3 │ audio/mpeg │ 478848 │  885809208 │ NULL   │            16 │        1 │                       96000 │ 2013-12-11 16:15:52 │ 2016-02-09 18:36:42 │ User3     │ User3     │          229 │      441 │      192 │ SPECTROGRAM │ 2016-06-20 18:10:09 │ 2016-06-20 18:10:09 │ User3     │ User3     │      192 │ 1466439009512o5iSPsZICAY7T8GR │ NULL    │ image/png   │      0 │   417860 │ 2276365895 │    1048 │     578 │ NULL    │ 2016-06-20 18:10:09 │ 2016-06-20 18:10:09 │ User3     │ User3     │ <POINT (5.677 45.184)> │ 2fcdad52-c712-4e92-9ad8-4e58b7c80336 │
# │    441 │ 13867749528019ZTeQN2bXAkp7vVn │ ESPECE │ Gryllus campestris                        │ MNHN             │ SO              │ 2014-441       │      1 │ NULL       │      1 │ 2016-06-30 00:00:00    │ NULL                 │ [NULL]                                                                           │ Avisoft recorder-carte son Motu │ CM16 Avisoft │        0 │                     96000 │               16 │       5 │                 1030852 │                       -1 │                  18 │ 26          │ [NULL]                      │ appel - male isolé               │ NULL    │ [NULL]              │ Europe          │ France           │ Grenoble                                             │ 45.183586 │  5.676636 │     NULL │ Nombreux autres enregistrements disponibles │ 2013-12-11 16:15:52 │ 2020-05-18 22:02:11 │ User3   │ User1   │               0 │             100 │          0 │ cc-by-nc-nd │                       9311 │    441 │                  10 │             10 │                        2 │ Etude du spécimen │ Etude du spécimen │     11 │ 2016-06-17 10:33:02 │ 2016-06-17 10:33:02 │ admin    │ admin    │           106 │     441 │        65 │              100 │ 2013-12-11 16:15:52 │ 2016-02-09 18:36:42 │ User3     │ User3     │        65 │        1 │                  1 │ Orthoptera │ Gryllidae      │ Gryllus     │ campestris          │ NULL                      │ Linnaeus, 1758            │ Gryllus campestris Linnaeus, 1758             │ 2013-12-11 16:15:52 │ 2017-01-17 12:48:53 │ User3     │ User1     │                1881 │          65 │ NULL   │ Grillon des champs       │ 2017-01-17 12:48:53 │ 2017-01-17 12:48:53 │ User1     │ User1     │                1 │                          1 │ Insectes     │ Insects      │        1 │ 2016-06-17 10:33:02 │ 2016-06-17 10:33:02 │ admin     │ admin     │           106 │      441 │         7 │ 2013-12-11 16:15:52 │ 2016-02-09 18:36:42 │ User3     │ User3     │         7 │ User3  │ 2013-10-04 11:47:02 │ 2016-02-09 13:57:35 │ User1     │ User3     │           NULL │     NULL │       NULL │ NULL         │ NULL         │ NULL      │ NULL      │       NULL │ NULL   │ NULL    │ NULL         │ NULL         │ NULL      │ NULL      │            NULL │     NULL │        NULL │ NULL         │ NULL         │ NULL      │ NULL      │        NULL │ NULL               │ NULL              │ NULL             │              NULL │               NULL │         NULL │ NULL       │ NULL         │ NULL         │ NULL      │ NULL      │            173 │      441 │ 1453824248000YEjjaaH69KxXmDEj │ MP3    │ 2016/01/26/MNHN_SO_2014-441 │ 1453824248000YEjjaaH69KxXmDEj.mp3 │ audio/mpeg │ 478848 │  885809208 │ NULL   │            16 │        1 │                       96000 │ 2013-12-11 16:15:52 │ 2016-02-09 18:36:42 │ User3     │ User3     │          229 │      441 │      192 │ SPECTROGRAM │ 2016-06-20 18:10:09 │ 2016-06-20 18:10:09 │ User3     │ User3     │      192 │ 1466439009512o5iSPsZICAY7T8GR │ NULL    │ image/png   │      0 │   417860 │ 2276365895 │    1048 │     578 │ NULL    │ 2016-06-20 18:10:09 │ 2016-06-20 18:10:09 │ User3     │ User3     │ <POINT (5.677 45.184)> │ 2fcdad52-c712-4e92-9ad8-4e58b7c80336 │
# │    441 │ 13867749528019ZTeQN2bXAkp7vVn │ ESPECE │ Gryllus campestris                        │ MNHN             │ SO              │ 2014-441       │      1 │ NULL       │      1 │ 2016-06-30 00:00:00    │ NULL                 │ [NULL]                                                                           │ Avisoft recorder-carte son Motu │ CM16 Avisoft │        0 │                     96000 │               16 │       5 │                 1030852 │                       -1 │                  18 │ 26          │ [NULL]                      │ appel - male isolé               │ NULL    │ [NULL]              │ Europe          │ France           │ Grenoble                                             │ 45.183586 │  5.676636 │     NULL │ Nombreux autres enregistrements disponibles │ 2013-12-11 16:15:52 │ 2020-05-18 22:02:11 │ User3   │ User1   │               0 │             100 │          0 │ cc-by-nc-nd │                       9311 │    441 │                  10 │             10 │                        2 │ Etude du spécimen │ Etude du spécimen │     11 │ 2016-06-17 10:33:02 │ 2016-06-17 10:33:02 │ admin    │ admin    │           106 │     441 │        65 │              100 │ 2013-12-11 16:15:52 │ 2016-02-09 18:36:42 │ User3     │ User3     │        65 │        1 │                  1 │ Orthoptera │ Gryllidae      │ Gryllus     │ campestris          │ NULL                      │ Linnaeus, 1758            │ Gryllus campestris Linnaeus, 1758             │ 2013-12-11 16:15:52 │ 2017-01-17 12:48:53 │ User3     │ User1     │                1880 │          65 │ NULL   │ Grillon champêtre        │ 2017-01-17 12:48:53 │ 2017-01-17 12:48:53 │ User1     │ User1     │                1 │                          1 │ Insectes     │ Insects      │        1 │ 2016-06-17 10:33:02 │ 2016-06-17 10:33:02 │ admin     │ admin     │           106 │      441 │         7 │ 2013-12-11 16:15:52 │ 2016-02-09 18:36:42 │ User3     │ User3     │         7 │ User3  │ 2013-10-04 11:47:02 │ 2016-02-09 13:57:35 │ User1     │ User3     │           NULL │     NULL │       NULL │ NULL         │ NULL         │ NULL      │ NULL      │       NULL │ NULL   │ NULL    │ NULL         │ NULL         │ NULL      │ NULL      │            NULL │     NULL │        NULL │ NULL         │ NULL         │ NULL      │ NULL      │        NULL │ NULL               │ NULL              │ NULL             │              NULL │               NULL │         NULL │ NULL       │ NULL         │ NULL         │ NULL      │ NULL      │            173 │      441 │ 1453824248000YEjjaaH69KxXmDEj │ MP3    │ 2016/01/26/MNHN_SO_2014-441 │ 1453824248000YEjjaaH69KxXmDEj.mp3 │ audio/mpeg │ 478848 │  885809208 │ NULL   │            16 │        1 │                       96000 │ 2013-12-11 16:15:52 │ 2016-02-09 18:36:42 │ User3     │ User3     │        61012 │      441 │    35712 │ VIGNETTE    │ 2020-05-18 22:02:11 │ 2020-05-18 22:02:11 │ User1     │ User1     │    35712 │ 1585312596248NQcdwNWIp3ogfcXx │ NULL    │ image/jpeg  │      0 │   112182 │ 2192148173 │     800 │     450 │ User109 │ 2020-03-27 13:36:36 │ 2020-03-27 13:36:36 │ User1     │ User1     │ <POINT (5.677 45.184)> │ 2fcdad52-c712-4e92-9ad8-4e58b7c80336 │
# │      … │ …                             │ …      │ …                                         │ …                │ …               │ …              │      … │ …          │      … │ …                      │ …                    │ …                                                                                │ …                               │ …            │        … │                         … │                … │       … │                       … │                        … │                   … │ …           │ …                           │ …                                │ …       │ …                   │ …               │ …                │ …                                                    │         … │         … │        … │ …                                           │ …                   │ …                   │ …       │ …       │               … │               … │          … │ …           │                          … │      … │                   … │              … │                        … │ …                 │ …                 │      … │ …                   │ …                   │ …        │ …        │             … │       … │         … │                … │ …                   │ …                   │ …         │ …         │         … │        … │                  … │ …          │ …              │ …           │ …                   │ …                         │ …                         │ …                                             │ …                   │ …                   │ …         │ …         │                   … │           … │ …      │ …                        │ …                   │ …                   │ …         │ …         │                … │                          … │ …            │ …            │        … │ …                   │ …                   │ …         │ …         │             … │        … │         … │ …                   │ …                   │ …         │ …         │         … │ …      │ …                   │ …                   │ …         │ …         │              … │        … │          … │ …            │ …            │ …         │ …         │          … │ …      │ …       │ …            │ …            │ …         │ …         │               … │        … │           … │ …            │ …            │ …         │ …         │           … │ …                  │ …                 │ …                │                 … │                  … │            … │ …          │ …            │ …            │ …         │ …         │              … │        … │ …                             │ …      │ …                           │ …                                 │ …          │      … │          … │ …      │             … │        … │                           … │ …                   │ …                   │ …         │ …         │            … │        … │        … │ …           │ …                   │ …                   │ …         │ …         │        … │ …                             │ …       │ …           │      … │        … │          … │       … │       … │ …       │ …                   │ …                   │ …         │ …         │ …                      │ …                                    │
# └────────┴───────────────────────────────┴────────┴───────────────────────────────────────────┴──────────────────┴─────────────────┴────────────────┴────────┴────────────┴────────┴────────────────────────┴──────────────────────┴──────────────────────────────────────────────────────────────────────────────────┴─────────────────────────────────┴──────────────┴──────────┴───────────────────────────┴──────────────────┴─────────┴─────────────────────────┴──────────────────────────┴─────────────────────┴─────────────┴─────────────────────────────┴──────────────────────────────────┴─────────┴─────────────────────┴─────────────────┴──────────────────┴──────────────────────────────────────────────────────┴───────────┴───────────┴──────────┴─────────────────────────────────────────────┴─────────────────────┴─────────────────────┴─────────┴─────────┴─────────────────┴─────────────────┴────────────┴─────────────┴────────────────────────────┴────────┴─────────────────────┴────────────────┴──────────────────────────┴───────────────────┴───────────────────┴────────┴─────────────────────┴─────────────────────┴──────────┴──────────┴───────────────┴─────────┴───────────┴──────────────────┴─────────────────────┴─────────────────────┴───────────┴───────────┴───────────┴──────────┴────────────────────┴────────────┴────────────────┴─────────────┴─────────────────────┴───────────────────────────┴───────────────────────────┴───────────────────────────────────────────────┴─────────────────────┴─────────────────────┴───────────┴───────────┴─────────────────────┴─────────────┴────────┴──────────────────────────┴─────────────────────┴─────────────────────┴───────────┴───────────┴──────────────────┴────────────────────────────┴──────────────┴──────────────┴──────────┴─────────────────────┴─────────────────────┴───────────┴───────────┴───────────────┴──────────┴───────────┴─────────────────────┴─────────────────────┴───────────┴───────────┴───────────┴────────┴─────────────────────┴─────────────────────┴───────────┴───────────┴────────────────┴──────────┴────────────┴──────────────┴──────────────┴───────────┴───────────┴────────────┴────────┴─────────┴──────────────┴──────────────┴───────────┴───────────┴─────────────────┴──────────┴─────────────┴──────────────┴──────────────┴───────────┴───────────┴─────────────┴────────────────────┴───────────────────┴──────────────────┴───────────────────┴────────────────────┴──────────────┴────────────┴──────────────┴──────────────┴───────────┴───────────┴────────────────┴──────────┴───────────────────────────────┴────────┴─────────────────────────────┴───────────────────────────────────┴────────────┴────────┴────────────┴────────┴───────────────┴──────────┴─────────────────────────────┴─────────────────────┴─────────────────────┴───────────┴───────────┴──────────────┴──────────┴──────────┴─────────────┴─────────────────────┴─────────────────────┴───────────┴───────────┴──────────┴───────────────────────────────┴─────────┴─────────────┴────────┴──────────┴────────────┴─────────┴─────────┴─────────┴─────────────────────┴─────────────────────┴───────────┴───────────┴────────────────────────┴──────────────────────────────────────┘
